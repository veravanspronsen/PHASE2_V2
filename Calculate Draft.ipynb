# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
mass = [45* 10 **3, 65* 10**3]  # kg

radius = 3.0/2
A = 3 * np.pi * radius**2 # m^2
rho = 1025 # kg/m^3

# %%
for i in range(len(mass)):
    draft = mass[i] / (rho * A)
    print(f"Draft: {draft:.2f} m for mass {mass[i]/1000:.0f} tons")
# Out:
# Draft: 2.07 m for mass 45 tons
# Draft: 2.99 m for mass 65 tons
