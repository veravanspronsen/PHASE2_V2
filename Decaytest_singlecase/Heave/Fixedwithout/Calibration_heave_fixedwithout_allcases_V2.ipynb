# %% [markdown]
# # Batch calibratie van decay-bestanden (ongefilterd, start op t_init)
#
# Dit notebook verwerkt **meerdere `.h5m`-bestanden** achter elkaar en voert voor elk bestand een **3-staps calibratie** uit:
#
# 1. **Coarse search**
# 2. **Tussenstap / medium search**
# 3. **Fine search**
#
# De calibratie is aangepast zodat:
# - het **ongefilterde signaal** wordt gebruikt als referentie
# - experiment en simulatie allebei starten op **`t_init`** (de initiële amplitude)
# - de simulatie **niet** meer naar een later extremum wordt verschoven
# - de vergelijking gebeurt op **pieken én dalen ná `t_init`**
#
# Per bestand krijg je:
# - de beste lineaire en quadratische dampingcoëfficiënten
# - de score van elke zoekstap
# - een plot van de **best gecalibreerde simulatie** versus experiment
# - een samenvattende tabel aan het einde
#
# > Let op: dit notebook gaat ervan uit dat de kanaalnamen in de `.h5m`-bestanden overeenkomen met deze pitch-opzet.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import h5py
import OrcFxAPI

from pathlib import Path
from scipy.signal import find_peaks

plt.rcParams["figure.figsize"] = (14, 6)
plt.rcParams["axes.grid"] = True

# %% [markdown]
# ## Instellingen
#
# Kies hieronder:
# - het OrcaFlex-model
# - één map of een expliciete lijst met `.h5m`-bestanden
# - de ranges voor coarse / tussenstap / fine

# %%
# =========================
# PADEN
# =========================
model_path = r"c:\Users\verav\Desktop\Studie\Afstuderen\PHASE2_ORCA\Decay_opzet_fixed_fine.dat"

# Optie A: expliciete lijst
exp_paths = [
    r"C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_003_001_01_Decay1.h5m",
    r"C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_003_002_01_Decay1.h5m",
    r"C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_003_003_01_Decay1.h5m",
]

# exp_paths = [
#     r"C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_001_01_Decay1.h5m"
# ]

# Optie B: automatisch meerdere bestanden uit dezelfde map ophalen
# Laat use_glob = True om onderstaande pattern te gebruiken.
use_glob = False
exp_glob_pattern = r"C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\003\*.h5m"

# =========================
# PLOT / FIT SETTINGS
# =========================
LABEL_SIZE = 14
TICK_SIZE = 12
TITLE_SIZE = 16

lookback_window = 5.0
quiet_window_end = 12.0
quiet_window_length = 50.0

n = 6  # aantal extrema inclusief startpunt

# =========================
# COARSE / TUSSENSTAP / FINE
# =========================
coarse_lin_values = np.linspace(0, 1000, 7)
coarse_quad_values = np.linspace(0, 1000, 7)

mid_delta_lin = 300
mid_delta_quad = 300
mid_num_lin = 7
mid_num_quad = 7

fine_delta_lin = 50
fine_delta_quad = 50
fine_num_lin = 6
fine_num_quad = 6

# =========================
# OPSLAAN VAN PLOTS
# =========================
save_plots = True
plot_output_dir = Path("decay_plots")

# %%
def resolve_exp_paths(exp_paths, use_glob=False, exp_glob_pattern=None):
    if use_glob:
        if not exp_glob_pattern:
            raise ValueError("use_glob=True maar geen exp_glob_pattern opgegeven.")
        paths = sorted(str(p) for p in Path(exp_glob_pattern).parent.glob(Path(exp_glob_pattern).name))
    else:
        paths = [str(Path(p)) for p in exp_paths]

    paths = [p for p in paths if Path(p).suffix.lower() == ".h5m"]

    if not paths:
        raise ValueError("Geen .h5m-bestanden gevonden.")

    return paths


all_exp_paths = resolve_exp_paths(exp_paths, use_glob=use_glob, exp_glob_pattern=exp_glob_pattern)
print(f"Aantal bestanden gevonden: {len(all_exp_paths)}")
for p in all_exp_paths:
    print(" -", p)
# Out:
# Aantal bestanden gevonden: 4
#  - C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_001_01_Decay1.h5m
#  - C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_002_01_Decay1.h5m
#  - C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_003_01_Decay1.h5m
#  - C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_004_01_Decay1.h5m

# %% [markdown]
# ## Helperfuncties

# %%
def load_experiment_data(exp_path):
    with h5py.File(exp_path, "r") as f:
        t_filt = f["FittedSignals/time"][:]
        z_filt = f["FittedSignals/PITCH decay fit"][:]

        t_unfiltered = f["UnfilteredSignals/time"][:]
        z_unfiltered = f["UnfilteredSignals/PITCH (unfiltered)"][:]

    return t_filt, z_filt, t_unfiltered, z_unfiltered


def extract_decay_from_file(
    exp_path,
    lookback_window=5.0,
    quiet_window_end=12.0,
    quiet_window_length=50.0,
):
    t_filt, z_filt, t_unfiltered, z_unfiltered = load_experiment_data(exp_path)

    # Alleen nog gebruiken als globale referentie om rustige periode + zoekvenster te bepalen
    t_decay_start_guess = t_filt[0]

    # 1. rustige periode in ONGEFILTERD signaal voor z_eq
    quiet_start = t_decay_start_guess - quiet_window_end - quiet_window_length
    quiet_end = t_decay_start_guess - quiet_window_end
    mask_quiet = (t_unfiltered >= quiet_start) & (t_unfiltered <= quiet_end)

    if not np.any(mask_quiet):
        raise ValueError(f"Geen data gevonden in rustige periode voor {exp_path}")

    z_eq = np.mean(z_unfiltered[mask_quiet])

    # 2. initiële amplitude zoeken in ONGEFILTERD signaal
    search_start = t_decay_start_guess - lookback_window
    search_end = t_decay_start_guess
    mask_search = (t_unfiltered >= search_start) & (t_unfiltered <= search_end)

    if not np.any(mask_search):
        raise ValueError(f"Geen data gevonden in zoekvenster vóór decay-start voor {exp_path}")

    t_search = t_unfiltered[mask_search]
    z_search = z_unfiltered[mask_search]

    deviation = z_search - z_eq
    idx_local = np.argmax(np.abs(deviation))

    t_init = t_search[idx_local]
    z_init = z_search[idx_local]
    A0_signed = z_init - z_eq
    A0 = np.abs(A0_signed)

    # 3. decay-signaal DIRECT vanaf t_init in ONGEFILTERD signaal
    mask_decay = t_unfiltered >= t_init
    if not np.any(mask_decay):
        raise ValueError(f"Geen ongefilterde decay-data gevonden vanaf t_init voor {exp_path}")

    t_decay = t_unfiltered[mask_decay] - t_init
    z_decay = z_unfiltered[mask_decay] - z_eq

    fit_positive = A0_signed >= 0

    # prominence gebaseerd op initiële amplitude
    prom = 0.01 * abs(A0_signed) if abs(A0_signed) > 0 else None
    # print(f"z_eq: {z_eq:.4f}")

    return {
        "exp_path": exp_path,
        "t_filt": t_filt,
        "z_filt": z_filt,
        "t_unfiltered": t_unfiltered,
        "z_unfiltered": z_unfiltered,
        "z_eq": z_eq,
        "t_init": t_init,
        "z_init": z_init,
        "A0": A0,
        "A0_signed": A0_signed,
        "t_decay_start": t_init,
        "z_decay_start": z_init,
        "t_decay": t_decay,
        "z_decay": z_decay,
        "fit_positive": fit_positive,
        "prom": prom,
        "ref_delay": 0.0,
        "extremum_number": 0,
        "quiet_start": quiet_start,
        "quiet_end": quiet_end,
        "search_start": search_start,
        "search_end": search_end,
    }


def get_n_extrema_after_start(t, z, n=8, positive=True, prominence=None):
    t = np.asarray(t)
    z = np.asarray(z)

    if len(t) < 2:
        raise ValueError("Signaal is te kort om extrema na start te bepalen.")
    if n < 1:
        raise ValueError("n moet minstens 1 zijn.")

    t_rest = t[1:]
    z_rest = z[1:]

    peak_kwargs = {}
    if prominence is not None:
        peak_kwargs["prominence"] = prominence

    if positive:
        idx, _ = find_peaks(z_rest, **peak_kwargs)
    else:
        idx, _ = find_peaks(-z_rest, **peak_kwargs)

    if len(idx) < n:
        raise ValueError(f"Te weinig extrema gevonden na start: {len(idx)} gevonden, {n} nodig.")

    idx = idx[:n]

    return t_rest[idx], z_rest[idx]



def compute_extrema_nrmse(z_sim_troughs, z_exp_troughs, z_sim_peaks, z_exp_peaks):
    z_sim_peaks = np.asarray(z_sim_peaks, dtype=float)
    z_exp_peaks = np.asarray(z_exp_peaks, dtype=float)
    z_sim_troughs = np.asarray(z_sim_troughs, dtype=float)
    z_exp_troughs = np.asarray(z_exp_troughs, dtype=float)

    n_peaks = min(len(z_sim_peaks), len(z_exp_peaks))
    n_troughs = min(len(z_sim_troughs), len(z_exp_troughs))

    if n_peaks == 0:
        raise ValueError("Geen overeenkomstige pieken gevonden voor de score.")
    if n_troughs == 0:
        raise ValueError("Geen overeenkomstige dalen gevonden voor de score.")

    z_sim_peaks = z_sim_peaks[:n_peaks]
    z_exp_peaks = z_exp_peaks[:n_peaks]
    z_sim_troughs = z_sim_troughs[:n_troughs]
    z_exp_troughs = z_exp_troughs[:n_troughs]

    def compute_nrmse(sim, exp):
        scale = max(np.max(np.abs(exp)), 1e-6)
        return np.sqrt(np.mean((sim - exp) ** 2)) / scale

    nrmse_peaks = compute_nrmse(z_sim_peaks, z_exp_peaks)
    nrmse_troughs = compute_nrmse(z_sim_troughs, z_exp_troughs)

    total_score = 0.5 * (nrmse_peaks + nrmse_troughs)

    return {
        "score": total_score,
        "nrmse_peaks": nrmse_peaks,
        "nrmse_troughs": nrmse_troughs,
        "n_peaks_used": n_peaks,
        "n_troughs_used": n_troughs,
    }



def compute_period(signal_t, signal_z, positive=True, prominence=0.01):
    if positive:
        idx, _ = find_peaks(signal_z, prominence=prominence)
    else:
        idx, _ = find_peaks(-signal_z, prominence=prominence)

    if len(idx) < 2:
        return np.nan, idx

    periods = np.diff(signal_t[idx])
    return np.mean(periods), idx

# %%
def run_decay_simulation(c_lin, c_quad, A0_signed, model_path):
    model = OrcFxAPI.Model(model_path)
    constraint = model["decay_constraint"]
    floaters = model["floaters"]
    floatertype = model["Floatertype"]

    floatertype.OtherDampingLinearCoeffRy = c_lin
    floatertype.OtherDampingQuadraticCoeffRy = c_quad

    # Zelfde aanname als je originele notebook:
    floaters.InitialTrim = A0_signed

    model.RunSimulation()

    t_sim = np.array(model.general.TimeHistory("Time"))
    z_sim_raw = np.array(floaters.TimeHistory("Rotation 2"))

    n_tail = min(100, len(z_sim_raw))
    z_eq_sim = np.mean(z_sim_raw[-n_tail:])
    z_sim = z_sim_raw
    t_sim = t_sim - t_sim[0]

    # print(f"z_eq_sim: {z_eq_sim:.4f}")

    return t_sim, z_sim

# %%
def evaluate_candidate(c_lin, c_quad, exp_info, n, model_path):
    t_sim, z_sim = run_decay_simulation(
        c_lin=c_lin,
        c_quad=c_quad,
        A0_signed=exp_info["A0_signed"],
        model_path=model_path,
    )

    # GEEN shift meer: simulatie start al bij initiële amplitude
    t_sim_ext_peaks, z_sim_ext_peaks = get_n_extrema_after_start(
        t_sim,
        z_sim,
        n=n,
        positive=True,
        prominence=exp_info["prom"],
    )

    t_sim_ext_troughs, z_sim_ext_troughs = get_n_extrema_after_start(
        t_sim,
        z_sim,
        n=n,
        positive=False,
        prominence=exp_info["prom"],
    )

    score_info = compute_extrema_nrmse(
        z_sim_troughs=z_sim_ext_troughs,
        z_exp_troughs=exp_info["z_ref_troughs"],
        z_sim_peaks=z_sim_ext_peaks,
        z_exp_peaks=exp_info["z_ref_peaks"],
    )

    return {
        "c_lin": c_lin,
        "c_quad": c_quad,
        "score": score_info["score"],
        "score_peaks": score_info["nrmse_peaks"],
        "score_troughs": score_info["nrmse_troughs"],
        "n_peaks_used": score_info["n_peaks_used"],
        "n_troughs_used": score_info["n_troughs_used"],
        "t_sim": t_sim,
        "z_sim": z_sim,
        "t_sim_ext_peaks": t_sim_ext_peaks,
        "z_sim_ext_peaks": z_sim_ext_peaks,
        "t_sim_ext_troughs": t_sim_ext_troughs,
        "z_sim_ext_troughs": z_sim_ext_troughs,
    }


def run_grid_search(lin_values, quad_values, exp_info, n, model_path, stage_name="stage"):
    results = []
    best_result = None
    best_score = np.inf

    total = len(lin_values) * len(quad_values)
    counter = 0

    for c_lin in lin_values:
        for c_quad in quad_values:
            counter += 1
            try:
                result = evaluate_candidate(c_lin, c_quad, exp_info, n=n, model_path=model_path)
                results.append(result)

                print(
                    f"[{stage_name} {counter:>3}/{total}] "
                    f"lin={c_lin:.4f}, quad={c_quad:.4f}, "
                    f"score={result['score']:.6f} "
                    f"(peaks={result['score_peaks']:.6f}, troughs={result['score_troughs']:.6f})"
                )

                if np.isfinite(result["score"]) and result["score"] < best_score:
                    best_score = result["score"]
                    best_result = result

            except Exception as e:
                print(
                    f"[{stage_name} {counter:>3}/{total}] "
                    f"FOUT bij lin={c_lin:.4f}, quad={c_quad:.4f}: {e}"
                )
                results.append({
                    "c_lin": c_lin,
                    "c_quad": c_quad,
                    "score": np.nan,
                    "error": str(e),
                })

    return best_result, results


def make_centered_range(center, delta, num, lower_bound=0.0):
    vmin = max(lower_bound, center - delta)
    vmax = center + delta
    return np.linspace(vmin, vmax, num)

# %% [markdown]
# ## Verwerking van één bestand

# %%
def prepare_reference_extrema(exp_info, n):
    t_ref_peaks, z_ref_peaks = get_n_extrema_after_start(
        exp_info["t_decay"],
        exp_info["z_decay"],
        n=n,
        positive=True,
        prominence=exp_info["prom"],
    )

    t_ref_troughs, z_ref_troughs = get_n_extrema_after_start(
        exp_info["t_decay"],
        exp_info["z_decay"],
        n=n,
        positive=False,
        prominence=exp_info["prom"],
    )

    exp_info["t_ref_peaks"] = t_ref_peaks
    exp_info["z_ref_peaks"] = z_ref_peaks
    exp_info["t_ref_troughs"] = t_ref_troughs
    exp_info["z_ref_troughs"] = z_ref_troughs

    return exp_info


def calibrate_single_file(exp_path, model_path, n=8):
    exp_info = extract_decay_from_file(
        exp_path=exp_path,
        lookback_window=lookback_window,
        quiet_window_end=quiet_window_end,
        quiet_window_length=quiet_window_length,
    )
    exp_info = prepare_reference_extrema(exp_info, n=n)

    print("=" * 100)
    print(f"BESTAND: {exp_path}")
    print(f"A0_signed                = {exp_info['A0_signed']:.6f} degree")
    print(f"Start op t_init          = {exp_info['t_decay_start']:.6f} s")
    print(f"Reference delay          = {exp_info['ref_delay']:.6f} s")
    print(f"Extremum number for sim  = {exp_info['extremum_number']}")
    print("=" * 100)

    # 1. coarse
    best_coarse, results_coarse = run_grid_search(
        coarse_lin_values,
        coarse_quad_values,
        exp_info=exp_info,
        n=n,
        model_path=model_path,
        stage_name="coarse"
    )
    if best_coarse is None:
        raise RuntimeError(f"Geen geldige coarse-oplossing gevonden voor {exp_path}")

    # 2. tussenstap / medium
    mid_lin_values = make_centered_range(best_coarse["c_lin"], mid_delta_lin, mid_num_lin)
    mid_quad_values = make_centered_range(best_coarse["c_quad"], mid_delta_quad, mid_num_quad)

    best_mid, results_mid = run_grid_search(
        mid_lin_values,
        mid_quad_values,
        exp_info=exp_info,
        n=n,
        model_path=model_path,
        stage_name="mid"
    )
    if best_mid is None:
        raise RuntimeError(f"Geen geldige mid-oplossing gevonden voor {exp_path}")

    # 3. fine
    fine_lin_values = make_centered_range(best_mid["c_lin"], fine_delta_lin, fine_num_lin)
    fine_quad_values = make_centered_range(best_mid["c_quad"], fine_delta_quad, fine_num_quad)

    best_fine, results_fine = run_grid_search(
        fine_lin_values,
        fine_quad_values,
        exp_info=exp_info,
        n=n,
        model_path=model_path,
        stage_name="fine"
    )
    if best_fine is None:
        raise RuntimeError(f"Geen geldige fine-oplossing gevonden voor {exp_path}")

    T_exp, _ = compute_period(
        exp_info["t_decay"],
        exp_info["z_decay"],
        positive=exp_info["fit_positive"],
        prominence=exp_info["prom"] if exp_info["prom"] is not None else 0.01,
    )
    T_sim, _ = compute_period(
        best_fine["t_sim"],
        best_fine["z_sim"],
        positive=exp_info["fit_positive"],
        prominence=exp_info["prom"] if exp_info["prom"] is not None else 0.01,
    )

    return {
        "exp_info": exp_info,
        "best_coarse": best_coarse,
        "results_coarse": results_coarse,
        "best_mid": best_mid,
        "results_mid": results_mid,
        "best_fine": best_fine,
        "results_fine": results_fine,
        "T_exp": T_exp,
        "T_sim": T_sim,
    }

# %% [markdown]
# ## Batch-run over alle bestanden

# %%
batch_results = []
failed_files = []

for exp_path in all_exp_paths:
    try:
        result = calibrate_single_file(exp_path, model_path=model_path, n=n)
        batch_results.append(result)
    except Exception as e:
        failed_files.append({"exp_path": exp_path, "error": str(e)})
        print(f"\nMISLUKT voor {exp_path}\n{e}\n")
# Out:
# z_eq: -0.0419
# ====================================================================================================
# BESTAND: C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_001_01_Decay1.h5m
# A0_signed                = 6.991969 degree
# Start op t_init          = 176.874766 s
# Reference delay          = 0.000000 s
# Extremum number for sim  = 0
# ====================================================================================================
# z_eq_sim: 1.0908
# [coarse   1/49] lin=0.0000, quad=0.0000, score=0.273105 (peaks=0.300165, troughs=0.246045)
# z_eq_sim: 1.0611
# [coarse   2/49] lin=0.0000, quad=166.6667, score=0.256828 (peaks=0.281567, troughs=0.232089)
# z_eq_sim: 1.0328
# [coarse   3/49] lin=0.0000, quad=333.3333, score=0.241240 (peaks=0.263754, troughs=0.218727)
# z_eq_sim: 1.0059
# [coarse   4/49] lin=0.0000, quad=500.0000, score=0.226299 (peaks=0.246670, troughs=0.205927)
# z_eq_sim: 0.9803
# [coarse   5/49] lin=0.0000, quad=666.6667, score=0.211980 (peaks=0.230271, troughs=0.193689)
# z_eq_sim: 0.9559
# [coarse   6/49] lin=0.0000, quad=833.3333, score=0.198267 (peaks=0.214514, troughs=0.182020)
# z_eq_sim: 0.9326
# [coarse   7/49] lin=0.0000, quad=1000.0000, score=0.185099 (peaks=0.199361, troughs=0.170836)
# z_eq_sim: 0.7829
# [coarse   8/49] lin=166.6667, quad=0.0000, score=0.111685 (peaks=0.114604, troughs=0.108767)
# z_eq_sim: 0.7636
# [coarse   9/49] lin=166.6667, quad=166.6667, score=0.100768 (peaks=0.101761, troughs=0.099774)
# z_eq_sim: 0.7452
# [coarse  10/49] lin=166.6667, quad=333.3333, score=0.090402 (peaks=0.089446, troughs=0.091358)
# z_eq_sim: 0.7276
# [coarse  11/49] lin=166.6667, quad=500.0000, score=0.080603 (peaks=0.077654, troughs=0.083552)
# z_eq_sim: 0.7108
# [coarse  12/49] lin=166.6667, quad=666.6667, score=0.071402 (peaks=0.066396, troughs=0.076408)
# z_eq_sim: 0.6948
# [coarse  13/49] lin=166.6667, quad=833.3333, score=0.062851 (peaks=0.055711, troughs=0.069992)
# z_eq_sim: 0.6794
# [coarse  14/49] lin=166.6667, quad=1000.0000, score=0.055032 (peaks=0.045689, troughs=0.064376)
# z_eq_sim: 0.5523
# [coarse  15/49] lin=333.3333, quad=0.0000, score=0.047163 (peaks=0.043353, troughs=0.050973)
# z_eq_sim: 0.5402
# [coarse  16/49] lin=333.3333, quad=166.6667, score=0.052617 (peaks=0.050963, troughs=0.054272)
# z_eq_sim: 0.5287
# [coarse  17/49] lin=333.3333, quad=333.3333, score=0.058500 (peaks=0.058776, troughs=0.058224)
# z_eq_sim: 0.5176
# [coarse  18/49] lin=333.3333, quad=500.0000, score=0.064634 (peaks=0.066631, troughs=0.062637)
# z_eq_sim: 0.5070
# [coarse  19/49] lin=333.3333, quad=666.6667, score=0.070895 (peaks=0.074437, troughs=0.067353)
# z_eq_sim: 0.4968
# [coarse  20/49] lin=333.3333, quad=833.3333, score=0.077200 (peaks=0.082140, troughs=0.072260)
# z_eq_sim: 0.4870
# [coarse  21/49] lin=333.3333, quad=1000.0000, score=0.083490 (peaks=0.089695, troughs=0.077285)
# z_eq_sim: 0.3862
# [coarse  22/49] lin=500.0000, quad=0.0000, score=0.136208 (peaks=0.152911, troughs=0.119505)
# z_eq_sim: 0.3788
# [coarse  23/49] lin=500.0000, quad=166.6667, score=0.142080 (peaks=0.159461, troughs=0.124698)
# z_eq_sim: 0.3716
# [coarse  24/49] lin=500.0000, quad=333.3333, score=0.147821 (peaks=0.165854, troughs=0.129789)
# z_eq_sim: 0.3648
# [coarse  25/49] lin=500.0000, quad=500.0000, score=0.153435 (peaks=0.172093, troughs=0.134777)
# z_eq_sim: 0.3581
# [coarse  26/49] lin=500.0000, quad=666.6667, score=0.158924 (peaks=0.178185, troughs=0.139663)
# z_eq_sim: 0.3517
# [coarse  27/49] lin=500.0000, quad=833.3333, score=0.164290 (peaks=0.184133, troughs=0.144448)
# z_eq_sim: 0.3456
# [coarse  28/49] lin=500.0000, quad=1000.0000, score=0.169539 (peaks=0.189942, troughs=0.149136)
# z_eq_sim: 0.2689
# [coarse  29/49] lin=666.6667, quad=0.0000, score=0.216854 (peaks=0.243823, troughs=0.189885)
# z_eq_sim: 0.2644
# [coarse  30/49] lin=666.6667, quad=166.6667, score=0.221375 (peaks=0.248751, troughs=0.193999)
# z_eq_sim: 0.2600
# [coarse  31/49] lin=666.6667, quad=333.3333, score=0.225797 (peaks=0.253570, troughs=0.198025)
# z_eq_sim: 0.2557
# [coarse  32/49] lin=666.6667, quad=500.0000, score=0.230125 (peaks=0.258284, troughs=0.201966)
# z_eq_sim: 0.2516
# [coarse  33/49] lin=666.6667, quad=666.6667, score=0.234359 (peaks=0.262895, troughs=0.205824)
# z_eq_sim: 0.2476
# [coarse  34/49] lin=666.6667, quad=833.3333, score=0.238507 (peaks=0.267410, troughs=0.209604)
# z_eq_sim: 0.2438
# [coarse  35/49] lin=666.6667, quad=1000.0000, score=0.242570 (peaks=0.271832, troughs=0.213308)
# z_eq_sim: 0.1870
# [coarse  36/49] lin=833.3333, quad=0.0000, score=0.282900 (peaks=0.317015, troughs=0.248785)
# z_eq_sim: 0.1842
# [coarse  37/49] lin=833.3333, quad=166.6667, score=0.286372 (peaks=0.320759, troughs=0.251986)
# z_eq_sim: 0.1815
# [coarse  38/49] lin=833.3333, quad=333.3333, score=0.289775 (peaks=0.324425, troughs=0.255125)
# z_eq_sim: 0.1788
# [coarse  39/49] lin=833.3333, quad=500.0000, score=0.293111 (peaks=0.328020, troughs=0.258201)
# z_eq_sim: 0.1763
# [coarse  40/49] lin=833.3333, quad=666.6667, score=0.296383 (peaks=0.331548, troughs=0.261217)
# z_eq_sim: 0.1738
# [coarse  41/49] lin=833.3333, quad=833.3333, score=0.299594 (peaks=0.335011, troughs=0.264177)
# z_eq_sim: 0.1714
# [coarse  42/49] lin=833.3333, quad=1000.0000, score=0.302746 (peaks=0.338409, troughs=0.267083)
# z_eq_sim: 0.1301
# [coarse  43/49] lin=1000.0000, quad=0.0000, score=0.336712 (peaks=0.376065, troughs=0.297358)
# z_eq_sim: 0.1283
# [coarse  44/49] lin=1000.0000, quad=166.6667, score=0.339425 (peaks=0.378970, troughs=0.299879)
# z_eq_sim: 0.1266
# [coarse  45/49] lin=1000.0000, quad=333.3333, score=0.342091 (peaks=0.381826, troughs=0.302356)
# z_eq_sim: 0.1250
# [coarse  46/49] lin=1000.0000, quad=500.0000, score=0.344710 (peaks=0.384634, troughs=0.304786)
# z_eq_sim: 0.1234
# [coarse  47/49] lin=1000.0000, quad=666.6667, score=0.347285 (peaks=0.387394, troughs=0.307177)
# z_eq_sim: 0.1218
# [coarse  48/49] lin=1000.0000, quad=833.3333, score=0.349819 (peaks=0.390110, troughs=0.309528)
# z_eq_sim: 0.1203
# [coarse  49/49] lin=1000.0000, quad=1000.0000, score=0.352311 (peaks=0.392781, troughs=0.311841)
# z_eq_sim: 1.0229
# [mid   1/49] lin=33.3333, quad=0.0000, score=0.237261 (peaks=0.259191, troughs=0.215332)
# z_eq_sim: 1.0145
# [mid   2/49] lin=33.3333, quad=50.0000, score=0.232649 (peaks=0.253918, troughs=0.211380)
# z_eq_sim: 1.0063
# [mid   3/49] lin=33.3333, quad=100.0000, score=0.228096 (peaks=0.248712, troughs=0.207480)
# z_eq_sim: 0.9981
# [mid   4/49] lin=33.3333, quad=150.0000, score=0.223601 (peaks=0.243572, troughs=0.203631)
# z_eq_sim: 0.9901
# [mid   5/49] lin=33.3333, quad=200.0000, score=0.219164 (peaks=0.238496, troughs=0.199832)
# z_eq_sim: 0.9823
# [mid   6/49] lin=33.3333, quad=250.0000, score=0.214784 (peaks=0.233483, troughs=0.196085)
# z_eq_sim: 0.9745
# [mid   7/49] lin=33.3333, quad=300.0000, score=0.210471 (peaks=0.228532, troughs=0.192410)
# z_eq_sim: 0.8381
# [mid   8/49] lin=133.3333, quad=0.0000, score=0.140361 (peaks=0.147881, troughs=0.132840)
# z_eq_sim: 0.8317
# [mid   9/49] lin=133.3333, quad=50.0000, score=0.136716 (peaks=0.143661, troughs=0.129770)
# z_eq_sim: 0.8253
# [mid  10/49] lin=133.3333, quad=100.0000, score=0.133119 (peaks=0.139492, troughs=0.126747)
# z_eq_sim: 0.8190
# [mid  11/49] lin=133.3333, quad=150.0000, score=0.129572 (peaks=0.135372, troughs=0.123771)
# z_eq_sim: 0.8129
# [mid  12/49] lin=133.3333, quad=200.0000, score=0.126072 (peaks=0.131302, troughs=0.120841)
# z_eq_sim: 0.8068
# [mid  13/49] lin=133.3333, quad=250.0000, score=0.122619 (peaks=0.127280, troughs=0.117959)
# z_eq_sim: 0.8008
# [mid  14/49] lin=133.3333, quad=300.0000, score=0.119215 (peaks=0.123306, troughs=0.115124)
# z_eq_sim: 0.6819
# [mid  15/49] lin=233.3333, quad=0.0000, score=0.061411 (peaks=0.054685, troughs=0.068137)
# z_eq_sim: 0.6770
# [mid  16/49] lin=233.3333, quad=50.0000, score=0.058911 (peaks=0.051547, troughs=0.066274)
# z_eq_sim: 0.6722
# [mid  17/49] lin=233.3333, quad=100.0000, score=0.056490 (peaks=0.048486, troughs=0.064494)
# z_eq_sim: 0.6675
# [mid  18/49] lin=233.3333, quad=150.0000, score=0.054153 (peaks=0.045508, troughs=0.062798)
# z_eq_sim: 0.6628
# [mid  19/49] lin=233.3333, quad=200.0000, score=0.051907 (peaks=0.042623, troughs=0.061191)
# z_eq_sim: 0.6581
# [mid  20/49] lin=233.3333, quad=250.0000, score=0.049758 (peaks=0.039840, troughs=0.059676)
# z_eq_sim: 0.6536
# [mid  21/49] lin=233.3333, quad=300.0000, score=0.047715 (peaks=0.037175, troughs=0.058256)
# z_eq_sim: 0.5523
# [mid  22/49] lin=333.3333, quad=0.0000, score=0.047163 (peaks=0.043353, troughs=0.050973)
# z_eq_sim: 0.5486
# [mid  23/49] lin=333.3333, quad=50.0000, score=0.048738 (peaks=0.045595, troughs=0.051880)
# z_eq_sim: 0.5450
# [mid  24/49] lin=333.3333, quad=100.0000, score=0.050369 (peaks=0.047877, troughs=0.052861)
# z_eq_sim: 0.5414
# [mid  25/49] lin=333.3333, quad=150.0000, score=0.052048 (peaks=0.050188, troughs=0.053909)
# z_eq_sim: 0.5379
# [mid  26/49] lin=333.3333, quad=200.0000, score=0.053768 (peaks=0.052520, troughs=0.055017)
# z_eq_sim: 0.5344
# [mid  27/49] lin=333.3333, quad=250.0000, score=0.055519 (peaks=0.054858, troughs=0.056179)
# z_eq_sim: 0.5309
# [mid  28/49] lin=333.3333, quad=300.0000, score=0.057299 (peaks=0.057206, troughs=0.057392)
# z_eq_sim: 0.4459
# [mid  29/49] lin=433.3333, quad=0.0000, score=0.099934 (peaks=0.110798, troughs=0.089070)
# z_eq_sim: 0.4432
# [mid  30/49] lin=433.3333, quad=50.0000, score=0.101858 (peaks=0.113008, troughs=0.090708)
# z_eq_sim: 0.4404
# [mid  31/49] lin=433.3333, quad=100.0000, score=0.103772 (peaks=0.115202, troughs=0.092342)
# z_eq_sim: 0.4378
# [mid  32/49] lin=433.3333, quad=150.0000, score=0.105677 (peaks=0.117382, troughs=0.093972)
# z_eq_sim: 0.4351
# [mid  33/49] lin=433.3333, quad=200.0000, score=0.107571 (peaks=0.119546, troughs=0.095597)
# z_eq_sim: 0.4325
# [mid  34/49] lin=433.3333, quad=250.0000, score=0.109456 (peaks=0.121695, troughs=0.097216)
# z_eq_sim: 0.4299
# [mid  35/49] lin=433.3333, quad=300.0000, score=0.111330 (peaks=0.123830, troughs=0.098830)
# z_eq_sim: 0.3593
# [mid  36/49] lin=533.3333, quad=0.0000, score=0.153568 (peaks=0.172701, troughs=0.134436)
# z_eq_sim: 0.3573
# [mid  37/49] lin=533.3333, quad=50.0000, score=0.155258 (peaks=0.174573, troughs=0.135943)
# z_eq_sim: 0.3552
# [mid  38/49] lin=533.3333, quad=100.0000, score=0.156936 (peaks=0.176431, troughs=0.137440)
# z_eq_sim: 0.3532
# [mid  39/49] lin=533.3333, quad=150.0000, score=0.158602 (peaks=0.178276, troughs=0.138928)
# z_eq_sim: 0.3513
# [mid  40/49] lin=533.3333, quad=200.0000, score=0.160257 (peaks=0.180108, troughs=0.140407)
# z_eq_sim: 0.3493
# [mid  41/49] lin=533.3333, quad=250.0000, score=0.161901 (peaks=0.181926, troughs=0.141876)
# z_eq_sim: 0.3474
# [mid  42/49] lin=533.3333, quad=300.0000, score=0.163533 (peaks=0.183731, troughs=0.143335)
# z_eq_sim: 0.2892
# [mid  43/49] lin=633.3333, quad=0.0000, score=0.201956 (peaks=0.227188, troughs=0.176724)
# z_eq_sim: 0.2877
# [mid  44/49] lin=633.3333, quad=50.0000, score=0.203398 (peaks=0.228764, troughs=0.178031)
# z_eq_sim: 0.2862
# [mid  45/49] lin=633.3333, quad=100.0000, score=0.204830 (peaks=0.230330, troughs=0.179330)
# z_eq_sim: 0.2847
# [mid  46/49] lin=633.3333, quad=150.0000, score=0.206253 (peaks=0.231885, troughs=0.180620)
# z_eq_sim: 0.2832
# [mid  47/49] lin=633.3333, quad=200.0000, score=0.207666 (peaks=0.233429, troughs=0.181902)
# z_eq_sim: 0.2817
# [mid  48/49] lin=633.3333, quad=250.0000, score=0.209069 (peaks=0.234963, troughs=0.183175)
# z_eq_sim: 0.2803
# [mid  49/49] lin=633.3333, quad=300.0000, score=0.210463 (peaks=0.236486, troughs=0.184441)
# z_eq_sim: 0.6140
# [fine   1/36] lin=283.3333, quad=0.0000, score=0.037700 (peaks=0.025428, troughs=0.049972)
# z_eq_sim: 0.6131
# [fine   2/36] lin=283.3333, quad=10.0000, score=0.037561 (peaks=0.025276, troughs=0.049847)
# z_eq_sim: 0.6123
# [fine   3/36] lin=283.3333, quad=20.0000, score=0.037433 (peaks=0.025140, troughs=0.049726)
# z_eq_sim: 0.6114
# [fine   4/36] lin=283.3333, quad=30.0000, score=0.037315 (peaks=0.025019, troughs=0.049611)
# z_eq_sim: 0.6106
# [fine   5/36] lin=283.3333, quad=40.0000, score=0.037207 (peaks=0.024913, troughs=0.049501)
# z_eq_sim: 0.6097
# [fine   6/36] lin=283.3333, quad=50.0000, score=0.037110 (peaks=0.024823, troughs=0.049396)
# z_eq_sim: 0.5886
# [fine   7/36] lin=303.3333, quad=0.0000, score=0.037660 (peaks=0.027445, troughs=0.047874)
# z_eq_sim: 0.5878
# [fine   8/36] lin=303.3333, quad=10.0000, score=0.037777 (peaks=0.027673, troughs=0.047881)
# z_eq_sim: 0.5869
# [fine   9/36] lin=303.3333, quad=20.0000, score=0.037902 (peaks=0.027911, troughs=0.047892)
# z_eq_sim: 0.5861
# [fine  10/36] lin=303.3333, quad=30.0000, score=0.038034 (peaks=0.028160, troughs=0.047908)
# z_eq_sim: 0.5854
# [fine  11/36] lin=303.3333, quad=40.0000, score=0.038174 (peaks=0.028420, troughs=0.047929)
# z_eq_sim: 0.5846
# [fine  12/36] lin=303.3333, quad=50.0000, score=0.038322 (peaks=0.028689, troughs=0.047955)
# z_eq_sim: 0.5641
# [fine  13/36] lin=323.3333, quad=0.0000, score=0.043187 (peaks=0.037196, troughs=0.049178)
# z_eq_sim: 0.5634
# [fine  14/36] lin=323.3333, quad=10.0000, score=0.043454 (peaks=0.037604, troughs=0.049304)
# z_eq_sim: 0.5626
# [fine  15/36] lin=323.3333, quad=20.0000, score=0.043725 (peaks=0.038016, troughs=0.049435)
# z_eq_sim: 0.5619
# [fine  16/36] lin=323.3333, quad=30.0000, score=0.044000 (peaks=0.038431, troughs=0.049569)
# z_eq_sim: 0.5611
# [fine  17/36] lin=323.3333, quad=40.0000, score=0.044278 (peaks=0.038849, troughs=0.049708)
# z_eq_sim: 0.5603
# [fine  18/36] lin=323.3333, quad=50.0000, score=0.044560 (peaks=0.039271, troughs=0.049849)
# z_eq_sim: 0.5406
# [fine  19/36] lin=343.3333, quad=0.0000, score=0.051642 (peaks=0.049893, troughs=0.053392)
# z_eq_sim: 0.5399
# [fine  20/36] lin=343.3333, quad=10.0000, score=0.051982 (peaks=0.050357, troughs=0.053607)
# z_eq_sim: 0.5392
# [fine  21/36] lin=343.3333, quad=20.0000, score=0.052324 (peaks=0.050823, troughs=0.053825)
# z_eq_sim: 0.5385
# [fine  22/36] lin=343.3333, quad=30.0000, score=0.052667 (peaks=0.051289, troughs=0.054046)
# z_eq_sim: 0.5378
# [fine  23/36] lin=343.3333, quad=40.0000, score=0.053012 (peaks=0.051756, troughs=0.054268)
# z_eq_sim: 0.5371
# [fine  24/36] lin=343.3333, quad=50.0000, score=0.053358 (peaks=0.052223, troughs=0.054493)
# z_eq_sim: 0.5181
# [fine  25/36] lin=363.3333, quad=0.0000, score=0.061568 (peaks=0.063450, troughs=0.059685)
# z_eq_sim: 0.5174
# [fine  26/36] lin=363.3333, quad=10.0000, score=0.061941 (peaks=0.063926, troughs=0.059957)
# z_eq_sim: 0.5167
# [fine  27/36] lin=363.3333, quad=20.0000, score=0.062316 (peaks=0.064401, troughs=0.060231)
# z_eq_sim: 0.5160
# [fine  28/36] lin=363.3333, quad=30.0000, score=0.062691 (peaks=0.064877, troughs=0.060505)
# z_eq_sim: 0.5154
# [fine  29/36] lin=363.3333, quad=40.0000, score=0.063067 (peaks=0.065352, troughs=0.060781)
# z_eq_sim: 0.5147
# [fine  30/36] lin=363.3333, quad=50.0000, score=0.063443 (peaks=0.065827, troughs=0.061059)
# z_eq_sim: 0.4964
# [fine  31/36] lin=383.3333, quad=0.0000, score=0.072244 (peaks=0.077181, troughs=0.067308)
# z_eq_sim: 0.4958
# [fine  32/36] lin=383.3333, quad=10.0000, score=0.072632 (peaks=0.077654, troughs=0.067611)
# z_eq_sim: 0.4951
# [fine  33/36] lin=383.3333, quad=20.0000, score=0.073021 (peaks=0.078126, troughs=0.067915)
# z_eq_sim: 0.4945
# [fine  34/36] lin=383.3333, quad=30.0000, score=0.073409 (peaks=0.078598, troughs=0.068220)
# z_eq_sim: 0.4938
# [fine  35/36] lin=383.3333, quad=40.0000, score=0.073797 (peaks=0.079069, troughs=0.068526)
# z_eq_sim: 0.4932
# [fine  36/36] lin=383.3333, quad=50.0000, score=0.074186 (peaks=0.079540, troughs=0.068832)
# z_eq: -0.0608
# ====================================================================================================
# BESTAND: C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_002_01_Decay1.h5m
# A0_signed                = 11.172375 degree
# Start op t_init          = 58.294789 s
# Reference delay          = 0.000000 s
# Extremum number for sim  = 0
# ====================================================================================================
# z_eq_sim: 1.4114
# [coarse   1/49] lin=0.0000, quad=0.0000, score=0.391285 (peaks=0.451983, troughs=0.330587)
# z_eq_sim: 1.3736
# [coarse   2/49] lin=0.0000, quad=166.6667, score=0.366680 (peaks=0.422756, troughs=0.310605)
# z_eq_sim: 1.3363
# [coarse   3/49] lin=0.0000, quad=333.3333, score=0.343569 (peaks=0.395454, troughs=0.291684)
# z_eq_sim: 1.3000
# [coarse   4/49] lin=0.0000, quad=500.0000, score=0.321823 (peaks=0.369818, troughs=0.273828)
# z_eq_sim: 1.2647
# [coarse   5/49] lin=0.0000, quad=666.6667, score=0.301240 (peaks=0.345555, troughs=0.256926)
# z_eq_sim: 1.2305
# [coarse   6/49] lin=0.0000, quad=833.3333, score=0.281694 (peaks=0.322507, troughs=0.240882)
# z_eq_sim: 1.1975
# [coarse   7/49] lin=0.0000, quad=1000.0000, score=0.263258 (peaks=0.300717, troughs=0.225799)
# z_eq_sim: 1.1025
# [coarse   8/49] lin=166.6667, quad=0.0000, score=0.229280 (peaks=0.260736, troughs=0.197824)
# z_eq_sim: 1.0686
# [coarse   9/49] lin=166.6667, quad=166.6667, score=0.211678 (peaks=0.239996, troughs=0.183360)
# z_eq_sim: 1.0364
# [coarse  10/49] lin=166.6667, quad=333.3333, score=0.195007 (peaks=0.220304, troughs=0.169709)
# z_eq_sim: 1.0059
# [coarse  11/49] lin=166.6667, quad=500.0000, score=0.179187 (peaks=0.201587, troughs=0.156786)
# z_eq_sim: 0.9768
# [coarse  12/49] lin=166.6667, quad=666.6667, score=0.164220 (peaks=0.183878, troughs=0.144562)
# z_eq_sim: 0.9491
# [coarse  13/49] lin=166.6667, quad=833.3333, score=0.150015 (peaks=0.167014, troughs=0.133015)
# z_eq_sim: 0.9228
# [coarse  14/49] lin=166.6667, quad=1000.0000, score=0.136554 (peaks=0.150943, troughs=0.122164)
# z_eq_sim: 0.8144
# [coarse  15/49] lin=333.3333, quad=0.0000, score=0.103884 (peaks=0.113205, troughs=0.094564)
# z_eq_sim: 0.7900
# [coarse  16/49] lin=333.3333, quad=166.6667, score=0.092129 (peaks=0.099070, troughs=0.085187)
# z_eq_sim: 0.7670
# [coarse  17/49] lin=333.3333, quad=333.3333, score=0.081306 (peaks=0.085927, troughs=0.076686)
# z_eq_sim: 0.7451
# [coarse  18/49] lin=333.3333, quad=500.0000, score=0.071508 (peaks=0.073874, troughs=0.069141)
# z_eq_sim: 0.7244
# [coarse  19/49] lin=333.3333, quad=666.6667, score=0.062931 (peaks=0.063175, troughs=0.062687)
# z_eq_sim: 0.7048
# [coarse  20/49] lin=333.3333, quad=833.3333, score=0.055766 (peaks=0.054054, troughs=0.057478)
# z_eq_sim: 0.6861
# [coarse  21/49] lin=333.3333, quad=1000.0000, score=0.050278 (peaks=0.046930, troughs=0.053625)
# z_eq_sim: 0.5848
# [coarse  22/49] lin=500.0000, quad=0.0000, score=0.052200 (peaks=0.055967, troughs=0.048432)
# z_eq_sim: 0.5686
# [coarse  23/49] lin=500.0000, quad=166.6667, score=0.055494 (peaks=0.060229, troughs=0.050759)
# z_eq_sim: 0.5533
# [coarse  24/49] lin=500.0000, quad=333.3333, score=0.060030 (peaks=0.065886, troughs=0.054175)
# z_eq_sim: 0.5387
# [coarse  25/49] lin=500.0000, quad=500.0000, score=0.065401 (peaks=0.072427, troughs=0.058376)
# z_eq_sim: 0.5249
# [coarse  26/49] lin=500.0000, quad=666.6667, score=0.071316 (peaks=0.079525, troughs=0.063107)
# z_eq_sim: 0.5117
# [coarse  27/49] lin=500.0000, quad=833.3333, score=0.077550 (peaks=0.086931, troughs=0.068168)
# z_eq_sim: 0.4991
# [coarse  28/49] lin=500.0000, quad=1000.0000, score=0.083951 (peaks=0.094481, troughs=0.073420)
# z_eq_sim: 0.4138
# [coarse  29/49] lin=666.6667, quad=0.0000, score=0.113122 (peaks=0.131863, troughs=0.094380)
# z_eq_sim: 0.4034
# [coarse  30/49] lin=666.6667, quad=166.6667, score=0.119706 (peaks=0.139283, troughs=0.100128)
# z_eq_sim: 0.3936
# [coarse  31/49] lin=666.6667, quad=333.3333, score=0.126178 (peaks=0.146576, troughs=0.105780)
# z_eq_sim: 0.3841
# [coarse  32/49] lin=666.6667, quad=500.0000, score=0.132525 (peaks=0.153727, troughs=0.111324)
# z_eq_sim: 0.3751
# [coarse  33/49] lin=666.6667, quad=666.6667, score=0.138741 (peaks=0.160729, troughs=0.116752)
# z_eq_sim: 0.3666
# [coarse  34/49] lin=666.6667, quad=833.3333, score=0.144820 (peaks=0.167577, troughs=0.122063)
# z_eq_sim: 0.3583
# [coarse  35/49] lin=666.6667, quad=1000.0000, score=0.150757 (peaks=0.174268, troughs=0.127246)
# z_eq_sim: 0.2907
# [coarse  36/49] lin=833.3333, quad=0.0000, score=0.178727 (peaks=0.208039, troughs=0.149416)
# z_eq_sim: 0.2841
# [coarse  37/49] lin=833.3333, quad=166.6667, score=0.184172 (peaks=0.214081, troughs=0.154263)
# z_eq_sim: 0.2778
# [coarse  38/49] lin=833.3333, quad=333.3333, score=0.189483 (peaks=0.219978, troughs=0.158988)
# z_eq_sim: 0.2718
# [coarse  39/49] lin=833.3333, quad=500.0000, score=0.194659 (peaks=0.225734, troughs=0.163583)
# z_eq_sim: 0.2660
# [coarse  40/49] lin=833.3333, quad=666.6667, score=0.199700 (peaks=0.231341, troughs=0.168060)
# z_eq_sim: 0.2605
# [coarse  41/49] lin=833.3333, quad=833.3333, score=0.204619 (peaks=0.236812, troughs=0.172426)
# z_eq_sim: 0.2552
# [coarse  42/49] lin=833.3333, quad=1000.0000, score=0.209417 (peaks=0.242147, troughs=0.176686)
# z_eq_sim: 0.2035
# [coarse  43/49] lin=1000.0000, quad=0.0000, score=0.234241 (peaks=0.271491, troughs=0.196992)
# z_eq_sim: 0.1994
# [coarse  44/49] lin=1000.0000, quad=166.6667, score=0.238610 (peaks=0.276317, troughs=0.200904)
# z_eq_sim: 0.1954
# [coarse  45/49] lin=1000.0000, quad=333.3333, score=0.242876 (peaks=0.281031, troughs=0.204722)
# z_eq_sim: 0.1916
# [coarse  46/49] lin=1000.0000, quad=500.0000, score=0.247043 (peaks=0.285636, troughs=0.208450)
# z_eq_sim: 0.1879
# [coarse  47/49] lin=1000.0000, quad=666.6667, score=0.251114 (peaks=0.290137, troughs=0.212090)
# z_eq_sim: 0.1843
# [coarse  48/49] lin=1000.0000, quad=833.3333, score=0.255092 (peaks=0.294538, troughs=0.215647)
# z_eq_sim: 0.1809
# [coarse  49/49] lin=1000.0000, quad=1000.0000, score=0.258982 (peaks=0.298841, troughs=0.219123)
# z_eq_sim: 1.1996
# [mid   1/49] lin=33.3333, quad=700.0000, score=0.267617 (peaks=0.305871, troughs=0.229364)
# z_eq_sim: 1.1796
# [mid   2/49] lin=33.3333, quad=800.0000, score=0.256623 (peaks=0.292882, troughs=0.220364)
# z_eq_sim: 1.1601
# [mid   3/49] lin=33.3333, quad=900.0000, score=0.245955 (peaks=0.280276, troughs=0.211633)
# z_eq_sim: 1.1411
# [mid   4/49] lin=33.3333, quad=1000.0000, score=0.235654 (peaks=0.268144, troughs=0.203163)
# z_eq_sim: 1.1226
# [mid   5/49] lin=33.3333, quad=1100.0000, score=0.225665 (peaks=0.256353, troughs=0.194978)
# z_eq_sim: 1.1045
# [mid   6/49] lin=33.3333, quad=1200.0000, score=0.215981 (peaks=0.244887, troughs=0.187075)
# z_eq_sim: 1.0868
# [mid   7/49] lin=33.3333, quad=1300.0000, score=0.206571 (peaks=0.233735, troughs=0.179406)
# z_eq_sim: 1.0267
# [mid   8/49] lin=133.3333, quad=700.0000, score=0.186098 (peaks=0.209680, troughs=0.162517)
# z_eq_sim: 1.0092
# [mid   9/49] lin=133.3333, quad=800.0000, score=0.176983 (peaks=0.198880, troughs=0.155086)
# z_eq_sim: 0.9921
# [mid  10/49] lin=133.3333, quad=900.0000, score=0.168162 (peaks=0.188431, troughs=0.147894)
# z_eq_sim: 0.9756
# [mid  11/49] lin=133.3333, quad=1000.0000, score=0.159606 (peaks=0.178273, troughs=0.140938)
# z_eq_sim: 0.9595
# [mid  12/49] lin=133.3333, quad=1100.0000, score=0.151306 (peaks=0.168396, troughs=0.134215)
# z_eq_sim: 0.9439
# [mid  13/49] lin=133.3333, quad=1200.0000, score=0.143257 (peaks=0.158791, troughs=0.127723)
# z_eq_sim: 0.9287
# [mid  14/49] lin=133.3333, quad=1300.0000, score=0.135480 (peaks=0.149451, troughs=0.121509)
# z_eq_sim: 0.8649
# [mid  15/49] lin=233.3333, quad=700.0000, score=0.115686 (peaks=0.126348, troughs=0.105024)
# z_eq_sim: 0.8503
# [mid  16/49] lin=233.3333, quad=800.0000, score=0.108416 (peaks=0.117574, troughs=0.099258)
# z_eq_sim: 0.8361
# [mid  17/49] lin=233.3333, quad=900.0000, score=0.101416 (peaks=0.109079, troughs=0.093754)
# z_eq_sim: 0.8224
# [mid  18/49] lin=233.3333, quad=1000.0000, score=0.094691 (peaks=0.100865, troughs=0.088517)
# z_eq_sim: 0.8090
# [mid  19/49] lin=233.3333, quad=1100.0000, score=0.088247 (peaks=0.092934, troughs=0.083560)
# z_eq_sim: 0.7961
# [mid  20/49] lin=233.3333, quad=1200.0000, score=0.082096 (peaks=0.085297, troughs=0.078895)
# z_eq_sim: 0.7835
# [mid  21/49] lin=233.3333, quad=1300.0000, score=0.076268 (peaks=0.077999, troughs=0.074536)
# z_eq_sim: 0.7204
# [mid  22/49] lin=333.3333, quad=700.0000, score=0.061379 (peaks=0.061215, troughs=0.061543)
# z_eq_sim: 0.7086
# [mid  23/49] lin=333.3333, quad=800.0000, score=0.057073 (peaks=0.055735, troughs=0.058411)
# z_eq_sim: 0.6972
# [mid  24/49] lin=333.3333, quad=900.0000, score=0.053353 (peaks=0.050934, troughs=0.055772)
# z_eq_sim: 0.6861
# [mid  25/49] lin=333.3333, quad=1000.0000, score=0.050278 (peaks=0.046930, troughs=0.053625)
# z_eq_sim: 0.6753
# [mid  26/49] lin=333.3333, quad=1100.0000, score=0.047923 (peaks=0.043852, troughs=0.051993)
# z_eq_sim: 0.6649
# [mid  27/49] lin=333.3333, quad=1200.0000, score=0.046342 (peaks=0.041797, troughs=0.050887)
# z_eq_sim: 0.6547
# [mid  28/49] lin=333.3333, quad=1300.0000, score=0.045575 (peaks=0.040844, troughs=0.050306)
# z_eq_sim: 0.5951
# [mid  29/49] lin=433.3333, quad=700.0000, score=0.051373 (peaks=0.052555, troughs=0.050192)
# z_eq_sim: 0.5858
# [mid  30/49] lin=433.3333, quad=800.0000, score=0.053580 (peaks=0.055460, troughs=0.051701)
# z_eq_sim: 0.5768
# [mid  31/49] lin=433.3333, quad=900.0000, score=0.056206 (peaks=0.058843, troughs=0.053568)
# z_eq_sim: 0.5680
# [mid  32/49] lin=433.3333, quad=1000.0000, score=0.059155 (peaks=0.062576, troughs=0.055734)
# z_eq_sim: 0.5595
# [mid  33/49] lin=433.3333, quad=1100.0000, score=0.062364 (peaks=0.066586, troughs=0.058142)
# z_eq_sim: 0.5512
# [mid  34/49] lin=433.3333, quad=1200.0000, score=0.065771 (peaks=0.070797, troughs=0.060745)
# z_eq_sim: 0.5431
# [mid  35/49] lin=433.3333, quad=1300.0000, score=0.069319 (peaks=0.075147, troughs=0.063491)
# z_eq_sim: 0.4887
# [mid  36/49] lin=533.3333, quad=700.0000, score=0.085724 (peaks=0.097418, troughs=0.074031)
# z_eq_sim: 0.4815
# [mid  37/49] lin=533.3333, quad=800.0000, score=0.089640 (peaks=0.101974, troughs=0.077307)
# z_eq_sim: 0.4744
# [mid  38/49] lin=533.3333, quad=900.0000, score=0.093564 (peaks=0.106527, troughs=0.080601)
# z_eq_sim: 0.4675
# [mid  39/49] lin=533.3333, quad=1000.0000, score=0.097483 (peaks=0.111064, troughs=0.083902)
# z_eq_sim: 0.4609
# [mid  40/49] lin=533.3333, quad=1100.0000, score=0.101388 (peaks=0.115576, troughs=0.087199)
# z_eq_sim: 0.4544
# [mid  41/49] lin=533.3333, quad=1200.0000, score=0.105270 (peaks=0.120054, troughs=0.090486)
# z_eq_sim: 0.4481
# [mid  42/49] lin=533.3333, quad=1300.0000, score=0.109124 (peaks=0.124493, troughs=0.093755)
# z_eq_sim: 0.3996
# [mid  43/49] lin=633.3333, quad=700.0000, score=0.126665 (peaks=0.146490, troughs=0.106841)
# z_eq_sim: 0.3940
# [mid  44/49] lin=633.3333, quad=800.0000, score=0.130437 (peaks=0.150756, troughs=0.110117)
# z_eq_sim: 0.3885
# [mid  45/49] lin=633.3333, quad=900.0000, score=0.134162 (peaks=0.154969, troughs=0.113354)
# z_eq_sim: 0.3832
# [mid  46/49] lin=633.3333, quad=1000.0000, score=0.137839 (peaks=0.159128, troughs=0.116550)
# z_eq_sim: 0.3780
# [mid  47/49] lin=633.3333, quad=1100.0000, score=0.141468 (peaks=0.163230, troughs=0.119706)
# z_eq_sim: 0.3730
# [mid  48/49] lin=633.3333, quad=1200.0000, score=0.145049 (peaks=0.167278, troughs=0.122820)
# z_eq_sim: 0.3680
# [mid  49/49] lin=633.3333, quad=1300.0000, score=0.148577 (peaks=0.171269, troughs=0.125885)
# z_eq_sim: 0.7226
# [fine   1/36] lin=283.3333, quad=1250.0000, score=0.056697 (peaks=0.053921, troughs=0.059474)
# z_eq_sim: 0.7204
# [fine   2/36] lin=283.3333, quad=1270.0000, score=0.055900 (peaks=0.052871, troughs=0.058929)
# z_eq_sim: 0.7181
# [fine   3/36] lin=283.3333, quad=1290.0000, score=0.055124 (peaks=0.051845, troughs=0.058402)
# z_eq_sim: 0.7159
# [fine   4/36] lin=283.3333, quad=1310.0000, score=0.054370 (peaks=0.050847, troughs=0.057893)
# z_eq_sim: 0.7137
# [fine   5/36] lin=283.3333, quad=1330.0000, score=0.053638 (peaks=0.049875, troughs=0.057402)
# z_eq_sim: 0.7115
# [fine   6/36] lin=283.3333, quad=1350.0000, score=0.052930 (peaks=0.048931, troughs=0.056929)
# z_eq_sim: 0.6970
# [fine   7/36] lin=303.3333, quad=1250.0000, score=0.050502 (peaks=0.046283, troughs=0.054720)
# z_eq_sim: 0.6948
# [fine   8/36] lin=303.3333, quad=1270.0000, score=0.049928 (peaks=0.045520, troughs=0.054337)
# z_eq_sim: 0.6926
# [fine   9/36] lin=303.3333, quad=1290.0000, score=0.049383 (peaks=0.044791, troughs=0.053974)
# z_eq_sim: 0.6905
# [fine  10/36] lin=303.3333, quad=1310.0000, score=0.048866 (peaks=0.044100, troughs=0.053631)
# z_eq_sim: 0.6884
# [fine  11/36] lin=303.3333, quad=1330.0000, score=0.048378 (peaks=0.043447, troughs=0.053308)
# z_eq_sim: 0.6863
# [fine  12/36] lin=303.3333, quad=1350.0000, score=0.047919 (peaks=0.042833, troughs=0.053005)
# z_eq_sim: 0.6720
# [fine  13/36] lin=323.3333, quad=1250.0000, score=0.046703 (peaks=0.041903, troughs=0.051503)
# z_eq_sim: 0.6699
# [fine  14/36] lin=323.3333, quad=1270.0000, score=0.046412 (peaks=0.041521, troughs=0.051302)
# z_eq_sim: 0.6679
# [fine  15/36] lin=323.3333, quad=1290.0000, score=0.046153 (peaks=0.041184, troughs=0.051122)
# z_eq_sim: 0.6658
# [fine  16/36] lin=323.3333, quad=1310.0000, score=0.045927 (peaks=0.040891, troughs=0.050963)
# z_eq_sim: 0.6638
# [fine  17/36] lin=323.3333, quad=1330.0000, score=0.045734 (peaks=0.040643, troughs=0.050824)
# z_eq_sim: 0.6618
# [fine  18/36] lin=323.3333, quad=1350.0000, score=0.045573 (peaks=0.040440, troughs=0.050707)
# z_eq_sim: 0.6477
# [fine  19/36] lin=343.3333, quad=1250.0000, score=0.045745 (peaks=0.041486, troughs=0.050003)
# z_eq_sim: 0.6458
# [fine  20/36] lin=343.3333, quad=1270.0000, score=0.045760 (peaks=0.041528, troughs=0.049992)
# z_eq_sim: 0.6438
# [fine  21/36] lin=343.3333, quad=1290.0000, score=0.045807 (peaks=0.041612, troughs=0.050001)
# z_eq_sim: 0.6418
# [fine  22/36] lin=343.3333, quad=1310.0000, score=0.045884 (peaks=0.041738, troughs=0.050030)
# z_eq_sim: 0.6399
# [fine  23/36] lin=343.3333, quad=1330.0000, score=0.045991 (peaks=0.041904, troughs=0.050078)
# z_eq_sim: 0.6380
# [fine  24/36] lin=343.3333, quad=1350.0000, score=0.046128 (peaks=0.042110, troughs=0.050146)
# z_eq_sim: 0.6242
# [fine  25/36] lin=363.3333, quad=1250.0000, score=0.047583 (peaks=0.044903, troughs=0.050263)
# z_eq_sim: 0.6223
# [fine  26/36] lin=363.3333, quad=1270.0000, score=0.047865 (peaks=0.045301, troughs=0.050429)
# z_eq_sim: 0.6204
# [fine  27/36] lin=363.3333, quad=1290.0000, score=0.048171 (peaks=0.045730, troughs=0.050612)
# z_eq_sim: 0.6185
# [fine  28/36] lin=363.3333, quad=1310.0000, score=0.048500 (peaks=0.046189, troughs=0.050812)
# z_eq_sim: 0.6167
# [fine  29/36] lin=363.3333, quad=1330.0000, score=0.048852 (peaks=0.046676, troughs=0.051028)
# z_eq_sim: 0.6148
# [fine  30/36] lin=363.3333, quad=1350.0000, score=0.049226 (peaks=0.047191, troughs=0.051261)
# z_eq_sim: 0.6013
# [fine  31/36] lin=383.3333, quad=1250.0000, score=0.051655 (peaks=0.051183, troughs=0.052128)
# z_eq_sim: 0.5995
# [fine  32/36] lin=383.3333, quad=1270.0000, score=0.052133 (peaks=0.051820, troughs=0.052446)
# z_eq_sim: 0.5977
# [fine  33/36] lin=383.3333, quad=1290.0000, score=0.052626 (peaks=0.052476, troughs=0.052777)
# z_eq_sim: 0.5959
# [fine  34/36] lin=383.3333, quad=1310.0000, score=0.053136 (peaks=0.053151, troughs=0.053121)
# z_eq_sim: 0.5941
# [fine  35/36] lin=383.3333, quad=1330.0000, score=0.053658 (peaks=0.053838, troughs=0.053478)
# z_eq_sim: 0.5924
# [fine  36/36] lin=383.3333, quad=1350.0000, score=0.054193 (peaks=0.054538, troughs=0.053848)
# z_eq: -0.0653
# ====================================================================================================
# BESTAND: C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_003_01_Decay1.h5m
# A0_signed                = 10.228691 degree
# Start op t_init          = 136.225393 s
# Reference delay          = 0.000000 s
# Extremum number for sim  = 0
# ====================================================================================================
# z_eq_sim: 1.3715
# [coarse   1/49] lin=0.0000, quad=0.0000, score=0.374479 (peaks=0.422822, troughs=0.326136)
# z_eq_sim: 1.3321
# [coarse   2/49] lin=0.0000, quad=166.6667, score=0.351360 (peaks=0.396180, troughs=0.306539)
# z_eq_sim: 1.2940
# [coarse   3/49] lin=0.0000, quad=333.3333, score=0.329578 (peaks=0.371018, troughs=0.288137)
# z_eq_sim: 1.2573
# [coarse   4/49] lin=0.0000, quad=500.0000, score=0.308910 (peaks=0.347156, troughs=0.270664)
# z_eq_sim: 1.2222
# [coarse   5/49] lin=0.0000, quad=666.6667, score=0.289370 (peaks=0.324656, troughs=0.254083)
# z_eq_sim: 1.1885
# [coarse   6/49] lin=0.0000, quad=833.3333, score=0.270830 (peaks=0.303295, troughs=0.238366)
# z_eq_sim: 1.1562
# [coarse   7/49] lin=0.0000, quad=1000.0000, score=0.253155 (peaks=0.282938, troughs=0.223373)
# z_eq_sim: 1.0454
# [coarse   8/49] lin=166.6667, quad=0.0000, score=0.210243 (peaks=0.233753, troughs=0.186732)
# z_eq_sim: 1.0138
# [coarse   9/49] lin=166.6667, quad=166.6667, score=0.193720 (peaks=0.214833, troughs=0.172608)
# z_eq_sim: 0.9838
# [coarse  10/49] lin=166.6667, quad=333.3333, score=0.178048 (peaks=0.196847, troughs=0.159249)
# z_eq_sim: 0.9554
# [coarse  11/49] lin=166.6667, quad=500.0000, score=0.163156 (peaks=0.179737, troughs=0.146575)
# z_eq_sim: 0.9284
# [coarse  12/49] lin=166.6667, quad=666.6667, score=0.149020 (peaks=0.163520, troughs=0.134520)
# z_eq_sim: 0.9027
# [coarse  13/49] lin=166.6667, quad=833.3333, score=0.135611 (peaks=0.148157, troughs=0.123066)
# z_eq_sim: 0.8784
# [coarse  14/49] lin=166.6667, quad=1000.0000, score=0.122870 (peaks=0.133542, troughs=0.112199)
# z_eq_sim: 0.7622
# [coarse  15/49] lin=333.3333, quad=0.0000, score=0.084928 (peaks=0.091976, troughs=0.077880)
# z_eq_sim: 0.7404
# [coarse  16/49] lin=333.3333, quad=166.6667, score=0.074577 (peaks=0.080356, troughs=0.068798)
# z_eq_sim: 0.7198
# [coarse  17/49] lin=333.3333, quad=333.3333, score=0.065289 (peaks=0.069993, troughs=0.060586)
# z_eq_sim: 0.7002
# [coarse  18/49] lin=333.3333, quad=500.0000, score=0.057253 (peaks=0.061129, troughs=0.053377)
# z_eq_sim: 0.6816
# [coarse  19/49] lin=333.3333, quad=666.6667, score=0.050724 (peaks=0.054085, troughs=0.047364)
# z_eq_sim: 0.6639
# [coarse  20/49] lin=333.3333, quad=833.3333, score=0.046028 (peaks=0.049260, troughs=0.042796)
# z_eq_sim: 0.6471
# [coarse  21/49] lin=333.3333, quad=1000.0000, score=0.043451 (peaks=0.046992, troughs=0.039911)
# z_eq_sim: 0.5432
# [coarse  22/49] lin=500.0000, quad=0.0000, score=0.058170 (peaks=0.071675, troughs=0.044664)
# z_eq_sim: 0.5291
# [coarse  23/49] lin=500.0000, quad=166.6667, score=0.063756 (peaks=0.077923, troughs=0.049590)
# z_eq_sim: 0.5157
# [coarse  24/49] lin=500.0000, quad=333.3333, score=0.069874 (peaks=0.084688, troughs=0.055060)
# z_eq_sim: 0.5029
# [coarse  25/49] lin=500.0000, quad=500.0000, score=0.076294 (peaks=0.091756, troughs=0.060832)
# z_eq_sim: 0.4907
# [coarse  26/49] lin=500.0000, quad=666.6667, score=0.082865 (peaks=0.098978, troughs=0.066751)
# z_eq_sim: 0.4790
# [coarse  27/49] lin=500.0000, quad=833.3333, score=0.089486 (peaks=0.106254, troughs=0.072718)
# z_eq_sim: 0.4679
# [coarse  28/49] lin=500.0000, quad=1000.0000, score=0.096091 (peaks=0.113515, troughs=0.078668)
# z_eq_sim: 0.3827
# [coarse  29/49] lin=666.6667, quad=0.0000, score=0.130597 (peaks=0.154350, troughs=0.106844)
# z_eq_sim: 0.3738
# [coarse  30/49] lin=666.6667, quad=166.6667, score=0.136944 (peaks=0.161224, troughs=0.112665)
# z_eq_sim: 0.3652
# [coarse  31/49] lin=666.6667, quad=333.3333, score=0.143129 (peaks=0.167934, troughs=0.118324)
# z_eq_sim: 0.3570
# [coarse  32/49] lin=666.6667, quad=500.0000, score=0.149153 (peaks=0.174467, troughs=0.123840)
# z_eq_sim: 0.3492
# [coarse  33/49] lin=666.6667, quad=666.6667, score=0.155023 (peaks=0.180841, troughs=0.129205)
# z_eq_sim: 0.3417
# [coarse  34/49] lin=666.6667, quad=833.3333, score=0.160746 (peaks=0.187054, troughs=0.134438)
# z_eq_sim: 0.3345
# [coarse  35/49] lin=666.6667, quad=1000.0000, score=0.166332 (peaks=0.193126, troughs=0.139538)
# z_eq_sim: 0.2681
# [coarse  36/49] lin=833.3333, quad=0.0000, score=0.197676 (peaks=0.229268, troughs=0.166085)
# z_eq_sim: 0.2624
# [coarse  37/49] lin=833.3333, quad=166.6667, score=0.202726 (peaks=0.234725, troughs=0.170727)
# z_eq_sim: 0.2570
# [coarse  38/49] lin=833.3333, quad=333.3333, score=0.207649 (peaks=0.240053, troughs=0.175245)
# z_eq_sim: 0.2519
# [coarse  39/49] lin=833.3333, quad=500.0000, score=0.212454 (peaks=0.245258, troughs=0.179651)
# z_eq_sim: 0.2469
# [coarse  40/49] lin=833.3333, quad=666.6667, score=0.217146 (peaks=0.250341, troughs=0.183950)
# z_eq_sim: 0.2421
# [coarse  41/49] lin=833.3333, quad=833.3333, score=0.221727 (peaks=0.255309, troughs=0.188144)
# z_eq_sim: 0.2375
# [coarse  42/49] lin=833.3333, quad=1000.0000, score=0.226202 (peaks=0.260164, troughs=0.192239)
# z_eq_sim: 0.1874
# [coarse  43/49] lin=1000.0000, quad=0.0000, score=0.253591 (peaks=0.291373, troughs=0.215808)
# z_eq_sim: 0.1838
# [coarse  44/49] lin=1000.0000, quad=166.6667, score=0.257621 (peaks=0.295726, troughs=0.219517)
# z_eq_sim: 0.1804
# [coarse  45/49] lin=1000.0000, quad=333.3333, score=0.261562 (peaks=0.299983, troughs=0.223140)
# z_eq_sim: 0.1771
# [coarse  46/49] lin=1000.0000, quad=500.0000, score=0.265415 (peaks=0.304147, troughs=0.226682)
# z_eq_sim: 0.1740
# [coarse  47/49] lin=1000.0000, quad=666.6667, score=0.269182 (peaks=0.308221, troughs=0.230143)
# z_eq_sim: 0.1709
# [coarse  48/49] lin=1000.0000, quad=833.3333, score=0.272870 (peaks=0.312210, troughs=0.233529)
# z_eq_sim: 0.1679
# [coarse  49/49] lin=1000.0000, quad=1000.0000, score=0.276479 (peaks=0.316115, troughs=0.236842)
# z_eq_sim: 1.1545
# [mid   1/49] lin=33.3333, quad=700.0000, score=0.255225 (peaks=0.285326, troughs=0.225125)
# z_eq_sim: 1.1352
# [mid   2/49] lin=33.3333, quad=800.0000, score=0.244733 (peaks=0.273245, troughs=0.216221)
# z_eq_sim: 1.1163
# [mid   3/49] lin=33.3333, quad=900.0000, score=0.234561 (peaks=0.261538, troughs=0.207584)
# z_eq_sim: 1.0979
# [mid   4/49] lin=33.3333, quad=1000.0000, score=0.224696 (peaks=0.250204, troughs=0.199188)
# z_eq_sim: 1.0801
# [mid   5/49] lin=33.3333, quad=1100.0000, score=0.215102 (peaks=0.239180, troughs=0.191024)
# z_eq_sim: 1.0627
# [mid   6/49] lin=33.3333, quad=1200.0000, score=0.205770 (peaks=0.228454, troughs=0.183085)
# z_eq_sim: 1.0459
# [mid   7/49] lin=33.3333, quad=1300.0000, score=0.196690 (peaks=0.218016, troughs=0.175364)
# z_eq_sim: 0.9786
# [mid   8/49] lin=133.3333, quad=700.0000, score=0.171581 (peaks=0.189316, troughs=0.153846)
# z_eq_sim: 0.9621
# [mid   9/49] lin=133.3333, quad=800.0000, score=0.162925 (peaks=0.179355, troughs=0.146496)
# z_eq_sim: 0.9462
# [mid  10/49] lin=133.3333, quad=900.0000, score=0.154537 (peaks=0.169715, troughs=0.139359)
# z_eq_sim: 0.9307
# [mid  11/49] lin=133.3333, quad=1000.0000, score=0.146407 (peaks=0.160381, troughs=0.132433)
# z_eq_sim: 0.9157
# [mid  12/49] lin=133.3333, quad=1100.0000, score=0.138520 (peaks=0.151327, troughs=0.125713)
# z_eq_sim: 0.9011
# [mid  13/49] lin=133.3333, quad=1200.0000, score=0.130862 (peaks=0.142526, troughs=0.119197)
# z_eq_sim: 0.8870
# [mid  14/49] lin=133.3333, quad=1300.0000, score=0.123434 (peaks=0.133974, troughs=0.112894)
# z_eq_sim: 0.8184
# [mid  15/49] lin=233.3333, quad=700.0000, score=0.100133 (peaks=0.107986, troughs=0.092280)
# z_eq_sim: 0.8051
# [mid  16/49] lin=233.3333, quad=800.0000, score=0.093370 (peaks=0.100241, troughs=0.086498)
# z_eq_sim: 0.7921
# [mid  17/49] lin=233.3333, quad=900.0000, score=0.086881 (peaks=0.092796, troughs=0.080965)
# z_eq_sim: 0.7795
# [mid  18/49] lin=233.3333, quad=1000.0000, score=0.080685 (peaks=0.085663, troughs=0.075707)
# z_eq_sim: 0.7673
# [mid  19/49] lin=233.3333, quad=1100.0000, score=0.074785 (peaks=0.078861, troughs=0.070709)
# z_eq_sim: 0.7555
# [mid  20/49] lin=233.3333, quad=1200.0000, score=0.069202 (peaks=0.072416, troughs=0.065989)
# z_eq_sim: 0.7440
# [mid  21/49] lin=233.3333, quad=1300.0000, score=0.063970 (peaks=0.066370, troughs=0.061570)
# z_eq_sim: 0.6780
# [mid  22/49] lin=333.3333, quad=700.0000, score=0.049627 (peaks=0.052929, troughs=0.046326)
# z_eq_sim: 0.6674
# [mid  23/49] lin=333.3333, quad=800.0000, score=0.046805 (peaks=0.050029, troughs=0.043581)
# z_eq_sim: 0.6571
# [mid  24/49] lin=333.3333, quad=900.0000, score=0.044731 (peaks=0.048034, troughs=0.041428)
# z_eq_sim: 0.6471
# [mid  25/49] lin=333.3333, quad=1000.0000, score=0.043451 (peaks=0.046992, troughs=0.039911)
# z_eq_sim: 0.6374
# [mid  26/49] lin=333.3333, quad=1100.0000, score=0.042967 (peaks=0.046877, troughs=0.039058)
# z_eq_sim: 0.6280
# [mid  27/49] lin=333.3333, quad=1200.0000, score=0.043255 (peaks=0.047641, troughs=0.038869)
# z_eq_sim: 0.6188
# [mid  28/49] lin=333.3333, quad=1300.0000, score=0.044257 (peaks=0.049202, troughs=0.039313)
# z_eq_sim: 0.5578
# [mid  29/49] lin=433.3333, quad=700.0000, score=0.056836 (peaks=0.068051, troughs=0.045620)
# z_eq_sim: 0.5495
# [mid  30/49] lin=433.3333, quad=800.0000, score=0.060133 (peaks=0.071831, troughs=0.048434)
# z_eq_sim: 0.5414
# [mid  31/49] lin=433.3333, quad=900.0000, score=0.063632 (peaks=0.075804, troughs=0.051459)
# z_eq_sim: 0.5336
# [mid  32/49] lin=433.3333, quad=1000.0000, score=0.067278 (peaks=0.079918, troughs=0.054637)
# z_eq_sim: 0.5260
# [mid  33/49] lin=433.3333, quad=1100.0000, score=0.071028 (peaks=0.084131, troughs=0.057924)
# z_eq_sim: 0.5186
# [mid  34/49] lin=433.3333, quad=1200.0000, score=0.074848 (peaks=0.088410, troughs=0.061287)
# z_eq_sim: 0.5114
# [mid  35/49] lin=433.3333, quad=1300.0000, score=0.078713 (peaks=0.092729, troughs=0.064698)
# z_eq_sim: 0.4565
# [mid  36/49] lin=533.3333, quad=700.0000, score=0.098988 (peaks=0.117410, troughs=0.080565)
# z_eq_sim: 0.4501
# [mid  37/49] lin=533.3333, quad=800.0000, score=0.102952 (peaks=0.121747, troughs=0.084157)
# z_eq_sim: 0.4439
# [mid  38/49] lin=533.3333, quad=900.0000, score=0.106885 (peaks=0.126052, troughs=0.087718)
# z_eq_sim: 0.4379
# [mid  39/49] lin=533.3333, quad=1000.0000, score=0.110783 (peaks=0.130322, troughs=0.091245)
# z_eq_sim: 0.4319
# [mid  40/49] lin=533.3333, quad=1100.0000, score=0.114643 (peaks=0.134552, troughs=0.094734)
# z_eq_sim: 0.4262
# [mid  41/49] lin=533.3333, quad=1200.0000, score=0.118461 (peaks=0.138738, troughs=0.098183)
# z_eq_sim: 0.4206
# [mid  42/49] lin=533.3333, quad=1300.0000, score=0.122235 (peaks=0.142879, troughs=0.101591)
# z_eq_sim: 0.3723
# [mid  43/49] lin=633.3333, quad=700.0000, score=0.142480 (peaks=0.166691, troughs=0.118269)
# z_eq_sim: 0.3674
# [mid  44/49] lin=633.3333, quad=800.0000, score=0.146071 (peaks=0.170594, troughs=0.121548)
# z_eq_sim: 0.3626
# [mid  45/49] lin=633.3333, quad=900.0000, score=0.149605 (peaks=0.174441, troughs=0.124768)
# z_eq_sim: 0.3579
# [mid  46/49] lin=633.3333, quad=1000.0000, score=0.153089 (peaks=0.178236, troughs=0.127941)
# z_eq_sim: 0.3534
# [mid  47/49] lin=633.3333, quad=1100.0000, score=0.156518 (peaks=0.181967, troughs=0.131068)
# z_eq_sim: 0.3489
# [mid  48/49] lin=633.3333, quad=1200.0000, score=0.159899 (peaks=0.185648, troughs=0.134150)
# z_eq_sim: 0.3446
# [mid  49/49] lin=633.3333, quad=1300.0000, score=0.163230 (peaks=0.189280, troughs=0.137181)
# z_eq_sim: 0.7054
# [fine   1/36] lin=283.3333, quad=1050.0000, score=0.053729 (peaks=0.055872, troughs=0.051586)
# z_eq_sim: 0.7032
# [fine   2/36] lin=283.3333, quad=1070.0000, score=0.052936 (peaks=0.054986, troughs=0.050886)
# z_eq_sim: 0.7011
# [fine   3/36] lin=283.3333, quad=1090.0000, score=0.052166 (peaks=0.054128, troughs=0.050203)
# z_eq_sim: 0.6989
# [fine   4/36] lin=283.3333, quad=1110.0000, score=0.051418 (peaks=0.053297, troughs=0.049539)
# z_eq_sim: 0.6968
# [fine   5/36] lin=283.3333, quad=1130.0000, score=0.050694 (peaks=0.052495, troughs=0.048893)
# z_eq_sim: 0.6947
# [fine   6/36] lin=283.3333, quad=1150.0000, score=0.049995 (peaks=0.051723, troughs=0.048267)
# z_eq_sim: 0.6796
# [fine   7/36] lin=303.3333, quad=1050.0000, score=0.047345 (peaks=0.049507, troughs=0.045183)
# z_eq_sim: 0.6775
# [fine   8/36] lin=303.3333, quad=1070.0000, score=0.046801 (peaks=0.048935, troughs=0.044666)
# z_eq_sim: 0.6754
# [fine   9/36] lin=303.3333, quad=1090.0000, score=0.046285 (peaks=0.048398, troughs=0.044172)
# z_eq_sim: 0.6734
# [fine  10/36] lin=303.3333, quad=1110.0000, score=0.045799 (peaks=0.047898, troughs=0.043701)
# z_eq_sim: 0.6713
# [fine  11/36] lin=303.3333, quad=1130.0000, score=0.045343 (peaks=0.047433, troughs=0.043253)
# z_eq_sim: 0.6693
# [fine  12/36] lin=303.3333, quad=1150.0000, score=0.044916 (peaks=0.047005, troughs=0.042827)
# z_eq_sim: 0.6545
# [fine  13/36] lin=323.3333, quad=1050.0000, score=0.043734 (peaks=0.046730, troughs=0.040737)
# z_eq_sim: 0.6525
# [fine  14/36] lin=323.3333, quad=1070.0000, score=0.043494 (peaks=0.046538, troughs=0.040451)
# z_eq_sim: 0.6505
# [fine  15/36] lin=323.3333, quad=1090.0000, score=0.043287 (peaks=0.046385, troughs=0.040190)
# z_eq_sim: 0.6486
# [fine  16/36] lin=323.3333, quad=1110.0000, score=0.043113 (peaks=0.046270, troughs=0.039956)
# z_eq_sim: 0.6466
# [fine  17/36] lin=323.3333, quad=1130.0000, score=0.042970 (peaks=0.046193, troughs=0.039748)
# z_eq_sim: 0.6447
# [fine  18/36] lin=323.3333, quad=1150.0000, score=0.042857 (peaks=0.046147, troughs=0.039567)
# z_eq_sim: 0.6301
# [fine  19/36] lin=343.3333, quad=1050.0000, score=0.043281 (peaks=0.047846, troughs=0.038717)
# z_eq_sim: 0.6282
# [fine  20/36] lin=343.3333, quad=1070.0000, score=0.043355 (peaks=0.048017, troughs=0.038692)
# z_eq_sim: 0.6264
# [fine  21/36] lin=343.3333, quad=1090.0000, score=0.043458 (peaks=0.048222, troughs=0.038693)
# z_eq_sim: 0.6245
# [fine  22/36] lin=343.3333, quad=1110.0000, score=0.043590 (peaks=0.048459, troughs=0.038721)
# z_eq_sim: 0.6226
# [fine  23/36] lin=343.3333, quad=1130.0000, score=0.043751 (peaks=0.048727, troughs=0.038774)
# z_eq_sim: 0.6208
# [fine  24/36] lin=343.3333, quad=1150.0000, score=0.043939 (peaks=0.049026, troughs=0.038852)
# z_eq_sim: 0.6065
# [fine  25/36] lin=363.3333, quad=1050.0000, score=0.045838 (peaks=0.052352, troughs=0.039324)
# z_eq_sim: 0.6047
# [fine  26/36] lin=363.3333, quad=1070.0000, score=0.046180 (peaks=0.052811, troughs=0.039548)
# z_eq_sim: 0.6030
# [fine  27/36] lin=363.3333, quad=1090.0000, score=0.046545 (peaks=0.053294, troughs=0.039795)
# z_eq_sim: 0.6012
# [fine  28/36] lin=363.3333, quad=1110.0000, score=0.046931 (peaks=0.053800, troughs=0.040063)
# z_eq_sim: 0.5994
# [fine  29/36] lin=363.3333, quad=1130.0000, score=0.047338 (peaks=0.054326, troughs=0.040351)
# z_eq_sim: 0.5976
# [fine  30/36] lin=363.3333, quad=1150.0000, score=0.047766 (peaks=0.054873, troughs=0.040659)
# z_eq_sim: 0.5837
# [fine  31/36] lin=383.3333, quad=1050.0000, score=0.050795 (peaks=0.059299, troughs=0.042291)
# z_eq_sim: 0.5820
# [fine  32/36] lin=383.3333, quad=1070.0000, score=0.051330 (peaks=0.059948, troughs=0.042712)
# z_eq_sim: 0.5803
# [fine  33/36] lin=383.3333, quad=1090.0000, score=0.051880 (peaks=0.060612, troughs=0.043148)
# z_eq_sim: 0.5786
# [fine  34/36] lin=383.3333, quad=1110.0000, score=0.052444 (peaks=0.061289, troughs=0.043599)
# z_eq_sim: 0.5769
# [fine  35/36] lin=383.3333, quad=1130.0000, score=0.053021 (peaks=0.061980, troughs=0.044063)
# z_eq_sim: 0.5752
# [fine  36/36] lin=383.3333, quad=1150.0000, score=0.053611 (peaks=0.062682, troughs=0.044540)
# z_eq: -0.3177
# ====================================================================================================
# BESTAND: C:\Users\verav\Desktop\Studie\Afstuderen\Decay_Data\01_Rawdata\02\004\34224_03CB_02_004_004_01_Decay1.h5m
# A0_signed                = 6.388740 degree
# Start op t_init          = 32.797639 s
# Reference delay          = 0.000000 s
# Extremum number for sim  = 0
# ====================================================================================================
# z_eq_sim: 1.0171
# [coarse   1/49] lin=0.0000, quad=0.0000, score=0.292216 (peaks=0.272028, troughs=0.312403)
# z_eq_sim: 0.9907
# [coarse   2/49] lin=0.0000, quad=166.6667, score=0.276422 (peaks=0.254446, troughs=0.298397)
# z_eq_sim: 0.9657
# [coarse   3/49] lin=0.0000, quad=333.3333, score=0.261258 (peaks=0.237603, troughs=0.284913)
# z_eq_sim: 0.9418
# [coarse   4/49] lin=0.0000, quad=500.0000, score=0.246688 (peaks=0.221454, troughs=0.271922)
# z_eq_sim: 0.9190
# [coarse   5/49] lin=0.0000, quad=666.6667, score=0.232652 (peaks=0.205905, troughs=0.259399)
# z_eq_sim: 0.8972
# [coarse   6/49] lin=0.0000, quad=833.3333, score=0.219120 (peaks=0.190922, troughs=0.247318)
# z_eq_sim: 0.8764
# [coarse   7/49] lin=0.0000, quad=1000.0000, score=0.206069 (peaks=0.176471, troughs=0.235667)
# z_eq_sim: 0.7244
# [coarse   8/49] lin=166.6667, quad=0.0000, score=0.121004 (peaks=0.082534, troughs=0.159474)
# z_eq_sim: 0.7076
# [coarse   9/49] lin=166.6667, quad=166.6667, score=0.110079 (peaks=0.070545, troughs=0.149614)
# z_eq_sim: 0.6916
# [coarse  10/49] lin=166.6667, quad=333.3333, score=0.099594 (peaks=0.059079, troughs=0.140110)
# z_eq_sim: 0.6764
# [coarse  11/49] lin=166.6667, quad=500.0000, score=0.089563 (peaks=0.048175, troughs=0.130951)
# z_eq_sim: 0.6617
# [coarse  12/49] lin=166.6667, quad=666.6667, score=0.080025 (peaks=0.037921, troughs=0.122130)
# z_eq_sim: 0.6477
# [coarse  13/49] lin=166.6667, quad=833.3333, score=0.071124 (peaks=0.028581, troughs=0.113666)
# z_eq_sim: 0.6342
# [coarse  14/49] lin=166.6667, quad=1000.0000, score=0.063182 (peaks=0.020836, troughs=0.105529)
# z_eq_sim: 0.5087
# [coarse  15/49] lin=333.3333, quad=0.0000, score=0.059788 (peaks=0.073015, troughs=0.046561)
# z_eq_sim: 0.4984
# [coarse  16/49] lin=333.3333, quad=166.6667, score=0.061497 (peaks=0.081085, troughs=0.041909)
# z_eq_sim: 0.4885
# [coarse  17/49] lin=333.3333, quad=333.3333, score=0.063615 (peaks=0.089023, troughs=0.038206)
# z_eq_sim: 0.4790
# [coarse  18/49] lin=333.3333, quad=500.0000, score=0.066218 (peaks=0.096808, troughs=0.035629)
# z_eq_sim: 0.4698
# [coarse  19/49] lin=333.3333, quad=666.6667, score=0.069371 (peaks=0.104430, troughs=0.034312)
# z_eq_sim: 0.4610
# [coarse  20/49] lin=333.3333, quad=833.3333, score=0.073089 (peaks=0.111885, troughs=0.034293)
# z_eq_sim: 0.4525
# [coarse  21/49] lin=333.3333, quad=1000.0000, score=0.077326 (peaks=0.119173, troughs=0.035479)
# z_eq_sim: 0.3548
# [coarse  22/49] lin=500.0000, quad=0.0000, score=0.130772 (peaks=0.188185, troughs=0.073360)
# z_eq_sim: 0.3485
# [coarse  23/49] lin=500.0000, quad=166.6667, score=0.136324 (peaks=0.194315, troughs=0.078333)
# z_eq_sim: 0.3424
# [coarse  24/49] lin=500.0000, quad=333.3333, score=0.141774 (peaks=0.200302, troughs=0.083247)
# z_eq_sim: 0.3366
# [coarse  25/49] lin=500.0000, quad=500.0000, score=0.147122 (peaks=0.206151, troughs=0.088093)
# z_eq_sim: 0.3309
# [coarse  26/49] lin=500.0000, quad=666.6667, score=0.152367 (peaks=0.211867, troughs=0.092867)
# z_eq_sim: 0.3254
# [coarse  27/49] lin=500.0000, quad=833.3333, score=0.157509 (peaks=0.217455, troughs=0.097564)
# z_eq_sim: 0.3201
# [coarse  28/49] lin=500.0000, quad=1000.0000, score=0.162550 (peaks=0.222918, troughs=0.102182)
# z_eq_sim: 0.2467
# [coarse  29/49] lin=666.6667, quad=0.0000, score=0.214634 (peaks=0.280712, troughs=0.148556)
# z_eq_sim: 0.2429
# [coarse  30/49] lin=666.6667, quad=166.6667, score=0.218937 (peaks=0.285281, troughs=0.152593)
# z_eq_sim: 0.2391
# [coarse  31/49] lin=666.6667, quad=333.3333, score=0.223154 (peaks=0.289756, troughs=0.156552)
# z_eq_sim: 0.2355
# [coarse  32/49] lin=666.6667, quad=500.0000, score=0.227287 (peaks=0.294139, troughs=0.160435)
# z_eq_sim: 0.2320
# [coarse  33/49] lin=666.6667, quad=666.6667, score=0.231339 (peaks=0.298434, troughs=0.164243)
# z_eq_sim: 0.2286
# [coarse  34/49] lin=666.6667, quad=833.3333, score=0.235312 (peaks=0.302644, troughs=0.167980)
# z_eq_sim: 0.2253
# [coarse  35/49] lin=666.6667, quad=1000.0000, score=0.239209 (peaks=0.306771, troughs=0.171647)
# z_eq_sim: 0.1714
# [coarse  36/49] lin=833.3333, quad=0.0000, score=0.283259 (peaks=0.354738, troughs=0.211779)
# z_eq_sim: 0.1690
# [coarse  37/49] lin=833.3333, quad=166.6667, score=0.286548 (peaks=0.358191, troughs=0.214906)
# z_eq_sim: 0.1667
# [coarse  38/49] lin=833.3333, quad=333.3333, score=0.289780 (peaks=0.361581, troughs=0.217979)
# z_eq_sim: 0.1645
# [coarse  39/49] lin=833.3333, quad=500.0000, score=0.292950 (peaks=0.364902, troughs=0.220998)
# z_eq_sim: 0.1623
# [coarse  40/49] lin=833.3333, quad=666.6667, score=0.296065 (peaks=0.368165, troughs=0.223965)
# z_eq_sim: 0.1602
# [coarse  41/49] lin=833.3333, quad=833.3333, score=0.299126 (peaks=0.371371, troughs=0.226882)
# z_eq_sim: 0.1581
# [coarse  42/49] lin=833.3333, quad=1000.0000, score=0.302136 (peaks=0.374521, troughs=0.229750)
# z_eq_sim: 0.1191
# [coarse  43/49] lin=1000.0000, quad=0.0000, score=0.339087 (peaks=0.414362, troughs=0.263813)
# z_eq_sim: 0.1176
# [coarse  44/49] lin=1000.0000, quad=166.6667, score=0.341653 (peaks=0.417035, troughs=0.266271)
# z_eq_sim: 0.1162
# [coarse  45/49] lin=1000.0000, quad=333.3333, score=0.344178 (peaks=0.419665, troughs=0.268691)
# z_eq_sim: 0.1148
# [coarse  46/49] lin=1000.0000, quad=500.0000, score=0.346660 (peaks=0.422248, troughs=0.271073)
# z_eq_sim: 0.1135
# [coarse  47/49] lin=1000.0000, quad=666.6667, score=0.349104 (peaks=0.424790, troughs=0.273419)
# z_eq_sim: 0.1121
# [coarse  48/49] lin=1000.0000, quad=833.3333, score=0.351511 (peaks=0.427293, troughs=0.275729)
# z_eq_sim: 0.1108
# [coarse  49/49] lin=1000.0000, quad=1000.0000, score=0.353882 (peaks=0.429758, troughs=0.278006)
# z_eq_sim: 0.9519
# [mid   1/49] lin=33.3333, quad=0.0000, score=0.254451 (peaks=0.230024, troughs=0.278879)
# z_eq_sim: 0.9445
# [mid   2/49] lin=33.3333, quad=50.0000, score=0.249991 (peaks=0.225079, troughs=0.274902)
# z_eq_sim: 0.9373
# [mid   3/49] lin=33.3333, quad=100.0000, score=0.245582 (peaks=0.220193, troughs=0.270970)
# z_eq_sim: 0.9301
# [mid   4/49] lin=33.3333, quad=150.0000, score=0.241223 (peaks=0.215364, troughs=0.267082)
# z_eq_sim: 0.9231
# [mid   5/49] lin=33.3333, quad=200.0000, score=0.236914 (peaks=0.210590, troughs=0.263238)
# z_eq_sim: 0.9161
# [mid   6/49] lin=33.3333, quad=250.0000, score=0.232653 (peaks=0.205871, troughs=0.259436)
# z_eq_sim: 0.9093
# [mid   7/49] lin=33.3333, quad=300.0000, score=0.228441 (peaks=0.201206, troughs=0.255676)
# z_eq_sim: 0.7764
# [mid   8/49] lin=133.3333, quad=0.0000, score=0.151783 (peaks=0.116384, troughs=0.187183)
# z_eq_sim: 0.7708
# [mid   9/49] lin=133.3333, quad=50.0000, score=0.148190 (peaks=0.112420, troughs=0.183961)
# z_eq_sim: 0.7652
# [mid  10/49] lin=133.3333, quad=100.0000, score=0.144637 (peaks=0.108500, troughs=0.180774)
# z_eq_sim: 0.7598
# [mid  11/49] lin=133.3333, quad=150.0000, score=0.141123 (peaks=0.104624, troughs=0.177621)
# z_eq_sim: 0.7544
# [mid  12/49] lin=133.3333, quad=200.0000, score=0.137648 (peaks=0.100792, troughs=0.174503)
# z_eq_sim: 0.7491
# [mid  13/49] lin=133.3333, quad=250.0000, score=0.134211 (peaks=0.097003, troughs=0.171418)
# z_eq_sim: 0.7439
# [mid  14/49] lin=133.3333, quad=300.0000, score=0.130812 (peaks=0.093256, troughs=0.168367)
# z_eq_sim: 0.6296
# [mid  15/49] lin=233.3333, quad=0.0000, score=0.067281 (peaks=0.026182, troughs=0.108379)
# z_eq_sim: 0.6254
# [mid  16/49] lin=233.3333, quad=50.0000, score=0.065038 (peaks=0.024241, troughs=0.105835)
# z_eq_sim: 0.6212
# [mid  17/49] lin=233.3333, quad=100.0000, score=0.062966 (peaks=0.022609, troughs=0.103322)
# z_eq_sim: 0.6171
# [mid  18/49] lin=233.3333, quad=150.0000, score=0.061092 (peaks=0.021343, troughs=0.100841)
# z_eq_sim: 0.6131
# [mid  19/49] lin=233.3333, quad=200.0000, score=0.059448 (peaks=0.020495, troughs=0.098400)
# z_eq_sim: 0.6091
# [mid  20/49] lin=233.3333, quad=250.0000, score=0.058050 (peaks=0.020106, troughs=0.095993)
# z_eq_sim: 0.6052
# [mid  21/49] lin=233.3333, quad=300.0000, score=0.056903 (peaks=0.020187, troughs=0.093619)
# z_eq_sim: 0.5087
# [mid  22/49] lin=333.3333, quad=0.0000, score=0.059788 (peaks=0.073015, troughs=0.046561)
# z_eq_sim: 0.5056
# [mid  23/49] lin=333.3333, quad=50.0000, score=0.060262 (peaks=0.075448, troughs=0.045076)
# z_eq_sim: 0.5025
# [mid  24/49] lin=333.3333, quad=100.0000, score=0.060768 (peaks=0.077872, troughs=0.043665)
# z_eq_sim: 0.4994
# [mid  25/49] lin=333.3333, quad=150.0000, score=0.061309 (peaks=0.080284, troughs=0.042334)
# z_eq_sim: 0.4964
# [mid  26/49] lin=333.3333, quad=200.0000, score=0.061885 (peaks=0.082684, troughs=0.041086)
# z_eq_sim: 0.4934
# [mid  27/49] lin=333.3333, quad=250.0000, score=0.062500 (peaks=0.085072, troughs=0.039928)
# z_eq_sim: 0.4904
# [mid  28/49] lin=333.3333, quad=300.0000, score=0.063155 (peaks=0.087447, troughs=0.038862)
# z_eq_sim: 0.4100
# [mid  29/49] lin=433.3333, quad=0.0000, score=0.094357 (peaks=0.144957, troughs=0.043758)
# z_eq_sim: 0.4077
# [mid  30/49] lin=433.3333, quad=50.0000, score=0.096043 (peaks=0.147047, troughs=0.045039)
# z_eq_sim: 0.4054
# [mid  31/49] lin=433.3333, quad=100.0000, score=0.097736 (peaks=0.149122, troughs=0.046349)
# z_eq_sim: 0.4031
# [mid  32/49] lin=433.3333, quad=150.0000, score=0.099433 (peaks=0.151182, troughs=0.047685)
# z_eq_sim: 0.4009
# [mid  33/49] lin=433.3333, quad=200.0000, score=0.101134 (peaks=0.153227, troughs=0.049042)
# z_eq_sim: 0.3986
# [mid  34/49] lin=433.3333, quad=250.0000, score=0.102837 (peaks=0.155257, troughs=0.050417)
# z_eq_sim: 0.3964
# [mid  35/49] lin=433.3333, quad=300.0000, score=0.104540 (peaks=0.157273, troughs=0.051807)
# z_eq_sim: 0.3300
# [mid  36/49] lin=533.3333, quad=0.0000, score=0.148743 (peaks=0.208391, troughs=0.089096)
# z_eq_sim: 0.3283
# [mid  37/49] lin=533.3333, quad=50.0000, score=0.150348 (peaks=0.210137, troughs=0.090559)
# z_eq_sim: 0.3266
# [mid  38/49] lin=533.3333, quad=100.0000, score=0.151943 (peaks=0.211871, troughs=0.092015)
# z_eq_sim: 0.3249
# [mid  39/49] lin=533.3333, quad=150.0000, score=0.153529 (peaks=0.213593, troughs=0.093464)
# z_eq_sim: 0.3232
# [mid  40/49] lin=533.3333, quad=200.0000, score=0.155104 (peaks=0.215303, troughs=0.094905)
# z_eq_sim: 0.3215
# [mid  41/49] lin=533.3333, quad=250.0000, score=0.156670 (peaks=0.217002, troughs=0.096339)
# z_eq_sim: 0.3199
# [mid  42/49] lin=533.3333, quad=300.0000, score=0.158227 (peaks=0.218689, troughs=0.097766)
# z_eq_sim: 0.2653
# [mid  43/49] lin=633.3333, quad=0.0000, score=0.199116 (peaks=0.263828, troughs=0.134404)
# z_eq_sim: 0.2641
# [mid  44/49] lin=633.3333, quad=50.0000, score=0.200488 (peaks=0.265291, troughs=0.135686)
# z_eq_sim: 0.2628
# [mid  45/49] lin=633.3333, quad=100.0000, score=0.201852 (peaks=0.266744, troughs=0.136961)
# z_eq_sim: 0.2615
# [mid  46/49] lin=633.3333, quad=150.0000, score=0.203208 (peaks=0.268188, troughs=0.138228)
# z_eq_sim: 0.2603
# [mid  47/49] lin=633.3333, quad=200.0000, score=0.204555 (peaks=0.269623, troughs=0.139487)
# z_eq_sim: 0.2590
# [mid  48/49] lin=633.3333, quad=250.0000, score=0.205894 (peaks=0.271048, troughs=0.140739)
# z_eq_sim: 0.2578
# [mid  49/49] lin=633.3333, quad=300.0000, score=0.207224 (peaks=0.272465, troughs=0.141984)
# z_eq_sim: 0.6759
# [fine   1/36] lin=183.3333, quad=250.0000, score=0.090879 (peaks=0.049721, troughs=0.132037)
# z_eq_sim: 0.6741
# [fine   2/36] lin=183.3333, quad=270.0000, score=0.089690 (peaks=0.048438, troughs=0.130942)
# z_eq_sim: 0.6722
# [fine   3/36] lin=183.3333, quad=290.0000, score=0.088508 (peaks=0.047165, troughs=0.129852)
# z_eq_sim: 0.6704
# [fine   4/36] lin=183.3333, quad=310.0000, score=0.087334 (peaks=0.045902, troughs=0.128766)
# z_eq_sim: 0.6686
# [fine   5/36] lin=183.3333, quad=330.0000, score=0.086168 (peaks=0.044650, troughs=0.127686)
# z_eq_sim: 0.6668
# [fine   6/36] lin=183.3333, quad=350.0000, score=0.085009 (peaks=0.043408, troughs=0.126611)
# z_eq_sim: 0.6484
# [fine   7/36] lin=203.3333, quad=250.0000, score=0.075297 (peaks=0.033418, troughs=0.117177)
# z_eq_sim: 0.6467
# [fine   8/36] lin=203.3333, quad=270.0000, score=0.074231 (peaks=0.032325, troughs=0.116138)
# z_eq_sim: 0.6450
# [fine   9/36] lin=203.3333, quad=290.0000, score=0.073178 (peaks=0.031253, troughs=0.115103)
# z_eq_sim: 0.6433
# [fine  10/36] lin=203.3333, quad=310.0000, score=0.072139 (peaks=0.030205, troughs=0.114073)
# z_eq_sim: 0.6416
# [fine  11/36] lin=203.3333, quad=330.0000, score=0.071115 (peaks=0.029182, troughs=0.113048)
# z_eq_sim: 0.6399
# [fine  12/36] lin=203.3333, quad=350.0000, score=0.070107 (peaks=0.028187, troughs=0.112028)
# z_eq_sim: 0.6220
# [fine  13/36] lin=223.3333, quad=250.0000, score=0.062356 (peaks=0.021815, troughs=0.102896)
# z_eq_sim: 0.6203
# [fine  14/36] lin=223.3333, quad=270.0000, score=0.061593 (peaks=0.021275, troughs=0.101910)
# z_eq_sim: 0.6187
# [fine  15/36] lin=223.3333, quad=290.0000, score=0.060865 (peaks=0.020800, troughs=0.100929)
# z_eq_sim: 0.6171
# [fine  16/36] lin=223.3333, quad=310.0000, score=0.060175 (peaks=0.020392, troughs=0.099958)
# z_eq_sim: 0.6155
# [fine  17/36] lin=223.3333, quad=330.0000, score=0.059522 (peaks=0.020054, troughs=0.098991)
# z_eq_sim: 0.6139
# [fine  18/36] lin=223.3333, quad=350.0000, score=0.058909 (peaks=0.019789, troughs=0.098029)
# z_eq_sim: 0.5965
# [fine  19/36] lin=243.3333, quad=250.0000, score=0.055686 (peaks=0.022116, troughs=0.089256)
# z_eq_sim: 0.5950
# [fine  20/36] lin=243.3333, quad=270.0000, score=0.055449 (peaks=0.022566, troughs=0.088331)
# z_eq_sim: 0.5934
# [fine  21/36] lin=243.3333, quad=290.0000, score=0.055241 (peaks=0.023069, troughs=0.087412)
# z_eq_sim: 0.5919
# [fine  22/36] lin=243.3333, quad=310.0000, score=0.055059 (peaks=0.023621, troughs=0.086498)
# z_eq_sim: 0.5904
# [fine  23/36] lin=243.3333, quad=330.0000, score=0.054903 (peaks=0.024217, troughs=0.085589)
# z_eq_sim: 0.5889
# [fine  24/36] lin=243.3333, quad=350.0000, score=0.054769 (peaks=0.024853, troughs=0.084686)
# z_eq_sim: 0.5720
# [fine  25/36] lin=263.3333, quad=250.0000, score=0.054736 (peaks=0.033172, troughs=0.076301)
# z_eq_sim: 0.5705
# [fine  26/36] lin=263.3333, quad=270.0000, score=0.054742 (peaks=0.034044, troughs=0.075440)
# z_eq_sim: 0.5691
# [fine  27/36] lin=263.3333, quad=290.0000, score=0.054757 (peaks=0.034929, troughs=0.074586)
# z_eq_sim: 0.5677
# [fine  28/36] lin=263.3333, quad=310.0000, score=0.054782 (peaks=0.035826, troughs=0.073737)
# z_eq_sim: 0.5662
# [fine  29/36] lin=263.3333, quad=330.0000, score=0.054814 (peaks=0.036734, troughs=0.072894)
# z_eq_sim: 0.5648
# [fine  30/36] lin=263.3333, quad=350.0000, score=0.054854 (peaks=0.037650, troughs=0.072058)
# z_eq_sim: 0.5484
# [fine  31/36] lin=283.3333, quad=250.0000, score=0.055844 (peaks=0.047513, troughs=0.064176)
# z_eq_sim: 0.5471
# [fine  32/36] lin=283.3333, quad=270.0000, score=0.055938 (peaks=0.048482, troughs=0.063393)
# z_eq_sim: 0.5457
# [fine  33/36] lin=283.3333, quad=290.0000, score=0.056036 (peaks=0.049454, troughs=0.062617)
# z_eq_sim: 0.5443
# [fine  34/36] lin=283.3333, quad=310.0000, score=0.056139 (peaks=0.050429, troughs=0.061850)
# z_eq_sim: 0.5430
# [fine  35/36] lin=283.3333, quad=330.0000, score=0.056247 (peaks=0.051404, troughs=0.061090)
# z_eq_sim: 0.5416
# [fine  36/36] lin=283.3333, quad=350.0000, score=0.056360 (peaks=0.052381, troughs=0.060338)

# %% [markdown]
# ## Plot per bestand: beste gecalibreerde simulatie vanaf t_init

# %%
if save_plots:
    plot_output_dir.mkdir(parents=True, exist_ok=True)

for result in batch_results:
    exp_info = result["exp_info"]
    best = result["best_fine"]

    t_decay = exp_info["t_decay"]
    z_decay = exp_info["z_decay"]

    t_sim = best["t_sim"]
    z_sim = best["z_sim"]

   
    t_max = t_decay[-1]
    mask_sim = t_sim <= t_max
    t_sim_plot = t_sim[mask_sim]
    z_sim_plot = z_sim[mask_sim]

    mask_decay = t_decay <= t_max
    t_decay_plot = t_decay[mask_decay]
    z_decay_plot = z_decay[mask_decay]

    

    plt.figure(figsize=(15, 7))
    plt.scatter(t_decay[0], z_decay[0], s=150, marker="*", label="Initial amplitude (experiment)", color="red")

    plt.plot(t_decay, z_decay, label="Experiment")
    plt.plot(t_sim_plot, z_sim_plot, label="Best calibrated simulation", color="orange")



    plt.scatter(exp_info["t_ref_troughs"], exp_info["z_ref_troughs"], s=70, label="Extrema (experiment)", color="#1f77b4")
    plt.scatter(best["t_sim_ext_troughs"], best["z_sim_ext_troughs"], s=70, marker="x", label="Extrema (simulation)", color="orange")
    plt.scatter(exp_info["t_ref_peaks"], exp_info["z_ref_peaks"], s=70,  color="#1f77b4")
    plt.scatter(best["t_sim_ext_peaks"], best["z_sim_ext_peaks"], s=70, marker="x", color="orange")

    fname = Path(exp_info["exp_path"]).name
    plt.xlabel("Time [s]", fontsize=LABEL_SIZE)
    plt.ylabel("Pitch [degrees]", fontsize=LABEL_SIZE)
    plt.title(
        "Calibrated pitch decay simulation \n"
        f"{fname} | linear={best['c_lin']:.4f}, quadratic={best['c_quad']:.4f}, "
        f"NRMSE={best['score']:.6f}",
        fontsize=TITLE_SIZE
    )
    plt.xlim(-5, t_sim_plot[-1] )
    plt.legend(fontsize=TICK_SIZE)

    if save_plots:
        safe_name = Path(exp_info["exp_path"]).stem.replace(" ", "_")
        plt.savefig(plot_output_dir / f"{safe_name}_best_calibration.png", dpi=150, bbox_inches="tight")

    plt.show()
    plt.savefig(plot_output_dir / f"{safe_name}_best_calibration.png", dpi=150, bbox_inches="tight")

# %% [markdown]
# ## Samenvatting van beste gecalibreerde coëfficiënten

# %%
summary_rows = []

for result in batch_results:
    exp_info = result["exp_info"]
    best_coarse = result["best_coarse"]
    best_mid = result["best_mid"]
    best_fine = result["best_fine"]

    summary_rows.append({
        "bestand": Path(exp_info["exp_path"]).name,
        "pad": exp_info["exp_path"],
        "A0_signed [deg]": exp_info["A0_signed"],
        "t_init [s]": exp_info["t_init"],
        "ref_delay [s]": exp_info["ref_delay"],
        "coarse_lin": best_coarse["c_lin"],
        "coarse_quad": best_coarse["c_quad"],
        "coarse_score": best_coarse["score"],
        "mid_lin": best_mid["c_lin"],
        "mid_quad": best_mid["c_quad"],
        "mid_score": best_mid["score"],
        "fine_lin": best_fine["c_lin"],
        "fine_quad": best_fine["c_quad"],
        "fine_score_total": best_fine["score"],
        "fine_score_peaks": best_fine["score_peaks"],
        "fine_score_troughs": best_fine["score_troughs"],
        "n_peaks_used": best_fine["n_peaks_used"],
        "n_troughs_used": best_fine["n_troughs_used"],
        "period_exp [s]": result["T_exp"],
        "period_sim [s]": result["T_sim"],
    })

df_summary = pd.DataFrame(summary_rows)
df_summary = df_summary.sort_values("bestand").reset_index(drop=True)

print("Aantal succesvol verwerkt:", len(df_summary))
display(df_summary)
# Out:
# Aantal succesvol verwerkt: 4
#                                bestand  \
# 0  34224_03CB_02_004_001_01_Decay1.h5m
# 1  34224_03CB_02_004_002_01_Decay1.h5m
# 2  34224_03CB_02_004_003_01_Decay1.h5m
# 3  34224_03CB_02_004_004_01_Decay1.h5m
#
#                                                  pad  A0_signed [deg]  \
# 0  C:\Users\verav\Desktop\Studie\Afstuderen\Decay...         6.991969
# 1  C:\Users\verav\Desktop\Studie\Afstuderen\Decay...        11.172375
# 2  C:\Users\verav\Desktop\Studie\Afstuderen\Decay...        10.228691
# 3  C:\Users\verav\Desktop\Studie\Afstuderen\Decay...         6.388740
#
#    t_init [s]  ref_delay [s]  coarse_lin  coarse_quad  coarse_score  \
# 0  176.874766            0.0  333.333333          0.0      0.047163
# 1   58.294789            0.0  333.333333       1000.0      0.050278
# 2  136.225393            0.0  333.333333       1000.0      0.043451
# 3   32.797639            0.0  333.333333          0.0      0.059788
#
#       mid_lin  mid_quad  mid_score    fine_lin  fine_quad  fine_score_total  \
# 0  333.333333       0.0   0.047163  283.333333       50.0          0.037110
# 1  333.333333    1300.0   0.045575  323.333333     1350.0          0.045573
# 2  333.333333    1100.0   0.042967  323.333333     1150.0          0.042857
# 3  233.333333     300.0   0.056903  263.333333      250.0          0.054736
#
#    fine_score_peaks  fine_score_troughs  n_peaks_used  n_troughs_used  \
# 0          0.024823            0.049396             6               6
# 1          0.040440            0.050707             6               6
# 2          0.046147            0.039567             6               6
# 3          0.033172            0.076301             6               6
#
#    period_exp [s]  period_sim [s]
# 0       10.027143        6.583333
# 1       11.057759        6.566667
# 2        9.584320        6.566667
# 3       11.017780        6.583333

# %% [markdown]
# ## Eventuele fouten

# %%
df_failed = pd.DataFrame(failed_files)
display(df_failed)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Optioneel: samenvatting exporteren naar Excel

# %%
save_summary_excel = True
summary_excel_path = Path("Pitch_fixedwithdeck_summary.xlsx")

if save_summary_excel and len(df_summary) > 0:
    df_summary.to_excel(summary_excel_path, index=False)
    print(f"Samenvatting opgeslagen naar: {summary_excel_path.resolve()}")
else:
    print("Excel-export staat uit of er is geen samenvatting beschikbaar.")
# Out:
# Samenvatting opgeslagen naar: C:\Users\verav\Downloads\Pitch_fixedwithoutdeck_summary.xlsx
